# %%
def get_upos(feat_str):
    # feat_str example: "ud=PROPN|pos=noun_prop|prc3=0|prc2=0|..."
    for feat in feat_str.split('|'):
        if feat.startswith('ud='):
            return feat[len('ud='):]  # Extract "PROPN"
    return None

def extract_features_from_parse(parse_lines):
    """
    Input:
      parse_lines: List[str], lines of the CoNLL-like parse (tokens only, no comment lines)
    Output:
      features: dict with syntactic features
    """
    tokens = []
    heads = []
    deprels = []
    upos_tags = []

    # Parse lines to extract relevant info
    for line in parse_lines:
        if line.startswith('#'):
            continue  # skip comment lines

        parts = line.strip().split('\t')
        if len(parts) < 8:
            continue  # skip malformed lines
        token_id = int(parts[0])
        word = parts[1]
        upos = get_upos(parts[5])
        head = int(parts[6])
        deprel = parts[7]

        tokens.append(word)
        upos_tags.append(upos)
        heads.append(head)
        deprels.append(deprel)

    n = len(tokens)

    # Dependency distances
    dep_distances = [abs((i+1) - head) if head != 0 else 0 for i, head in enumerate(heads)]
    avg_dep_distance = sum(dep_distances) / n if n > 0 else 0
    max_dep_distance = max(dep_distances) if dep_distances else 0
    long_deps_count = sum(d > 3 for d in dep_distances)

    # POS tag counts and ratios
    from collections import Counter
    pos_counts = Counter(upos_tags)

    noun_count = pos_counts.get('NOUN', 0) + pos_counts.get('PROPN', 0)
    verb_count = pos_counts.get('VERB', 0)
    adj_count = pos_counts.get('ADJ', 0)
    adv_count = pos_counts.get('ADV', 0)
    adp_count = pos_counts.get('ADP', 0)
    pron_count = pos_counts.get('PRON', 0)
    cconj_count = pos_counts.get('CCONJ', 0)
    num_count = pos_counts.get('NUM', 0)
    punct_count = pos_counts.get('PUNCT', 0)
    sconj_count = pos_counts.get('SCONJ', 0)
    part_count = pos_counts.get('PART', 0)
    det_count = pos_counts.get('DET', 0)
    aux_count = pos_counts.get('AUX', 0)
    intj_count = pos_counts.get('INTJ', 0)
    pipe_count = pos_counts.get('|', 0)  # assuming '|' shows up in the pos column

    total_content_words = noun_count + verb_count + adj_count + adv_count
    total_words = n

    verb_to_noun_ratio = (verb_count / noun_count) if noun_count > 0 else 0
    content_word_ratio = (total_content_words / total_words) if total_words > 0 else 0

    # Dependency relation counts
    dep_counts = Counter(deprels)
    sbj_count = dep_counts.get('SBJ', 0)
    obj_count = dep_counts.get('OBJ', 0)
    advcl_count = dep_counts.get('ADVCL', 0)
    acl_count = dep_counts.get('ACL', 0)
    conj_count = dep_counts.get('CONJ', 0)
    cc_count = dep_counts.get('CC', 0)

    # Tree structure
    children = {i+1: [] for i in range(n)}
    root = None
    for i, h in enumerate(heads, 1):
        if h == 0:
            root = i
        else:
            children[h].append(i)

    def tree_depth(node):
        if not children[node]:
            return 1
        else:
            return 1 + max(tree_depth(c) for c in children[node])

    max_depth = tree_depth(root) if root else 0

    dependents_counts = [len(children[h]) for h in children]
    avg_dependents = sum(dependents_counts) / n if n > 0 else 0
    max_dependents = max(dependents_counts) if dependents_counts else 0

    # Left and right dependents
    left_deps = sum(1 for i, h in enumerate(heads, 1) if h != 0 and h > i)
    right_deps = sum(1 for i, h in enumerate(heads, 1) if h != 0 and h < i)
    left_right_dep_ratio = (left_deps / right_deps) if right_deps != 0 else 0

    # Compose features
    features = {
        'avg_dep_distance': avg_dep_distance,
        'max_dep_distance': max_dep_distance,
        'long_deps_count': long_deps_count,
        'noun_count': noun_count,
        'verb_count': verb_count,
        'adj_count': adj_count,
        'adv_count': adv_count,
        'adp_count': adp_count,
        'pron_count': pron_count,
        'cconj_count': cconj_count,
        'num_count': num_count,
        'punct_count': punct_count,
        'sconj_count': sconj_count,
        'part_count': part_count,
        'det_count': det_count,
        'aux_count': aux_count,
        'intj_count': intj_count,
        'pipe_count': pipe_count,
        'verb_to_noun_ratio': verb_to_noun_ratio,
        'content_word_ratio': content_word_ratio,
        'sbj_count': sbj_count,
        'obj_count': obj_count,
        'advcl_count': advcl_count,
        'acl_count': acl_count,
        'conj_count': conj_count,
        'cc_count': cc_count,
        'max_depth': max_depth,
        'avg_dependents': avg_dependents,
        'max_dependents': max_dependents,
        'left_deps': left_deps,
        'right_deps': right_deps,
        'left_right_dep_ratio': left_right_dep_ratio,
        'total_words': total_words
    }

    return features


def extract_pos_tags_from_block(block):
    """
    Input:
      block: List[str], lines of the CoNLL-like parse (tokens only, no comment lines)
    Output:
      pos_tags: List[str] with POS tags
    """
    pos_tags = []
    for line in block:
        if line.startswith('#'):
            continue  # skip comment lines

        parts = line.strip().split('\t')
        parts = line.strip().split('\t')
        if len(parts) < 8:
            continue  # skip malformed lines
        upos = get_upos(parts[5])
        if upos:
            pos_tags.append(upos)
        else:
            pos_tags.append('UNKNOWN')

    return pos_tags

def extract_features_from_ud(ud_string):
    """Parse the 'ud=' string and return a dict of features."""
    if not ud_string.startswith('ud='):
        return {}
    feature_string = ud_string
    features = feature_string.split('|')
    feature_dict = {}
    for feat in features:
        if '=' in feat:
            k, v = feat.split('=', 1)
            feature_dict[k] = v
    return feature_dict

def extract_morph_features_from_block(block, all_features):
    """
    Extract morphological features from one CoNLL block.
    Returns: dict of {feature_name: list of values}
    """
    features_by_name = {feat: [] for feat in all_features}
    
    for line in block:
        if line.startswith('#'):
            continue
        parts = line.strip().split('\t')
        if len(parts) < 8:
            continue
        morph_dict = extract_features_from_ud(parts[5])
        for feat in all_features:
            features_by_name[feat].append(morph_dict.get(feat, "na"))  # "na" for missing
    return features_by_name

# %%
parse_lines = [
    "# text = أنا أحب أختي",
    "# treeTokens = أنا أحب أخت +ي",
    "1	أنا	أنا	NOM	_	ud=PRON|pos=pron|prc3=0|prc2=0|prc1=0|prc0=0|enc0=0|asp=na|vox=na|mod=na|gen=m|num=s|stt=i|cas=n|per=1|rat=y|token_type=baseword	2	SBJ	_	_",
    "2	أحب	أحب	VRB	_	ud=VERB|pos=verb|prc3=0|prc2=0|prc1=0|prc0=0|enc0=0|asp=i|vox=a|mod=u|gen=m|num=s|stt=na|cas=na|per=1|rat=n|token_type=baseword	0	---	_	_",
    "3	أخت	أخت	NOM	_	ud=NOUN|pos=noun|prc3=0|prc2=0|prc1=0|prc0=0|enc0=0|asp=na|vox=na|mod=na|gen=f|num=s|stt=c|cas=u|per=na|rat=r|token_type=baseword	2	OBJ	_	_",
    "4	+ي	+ي	NOM	_	ud=PRON|pos=pron|prc3=0|prc2=0|prc1=0|prc0=0|enc0=0|asp=na|vox=na|mod=na|gen=m|num=s|stt=d|cas=g|per=1|rat=na|token_type=enc0	3	IDF	_	_",
    ]

features = extract_features_from_parse(parse_lines)
print(features)

sentence = parse_lines[0].replace("# text = ", "").strip()
print(sentence)  # Output: أنا أحب أختي
# Out:
# {'avg_dep_distance': 0.75, 'max_dep_distance': 1, 'long_deps_count': 0, 'noun_count': 1, 'verb_count': 1, 'adj_count': 0, 'adv_count': 0, 'adp_count': 0, 'pron_count': 2, 'cconj_count': 0, 'num_count': 0, 'punct_count': 0, 'sconj_count': 0, 'part_count': 0, 'det_count': 0, 'aux_count': 0, 'intj_count': 0, 'pipe_count': 0, 'verb_to_noun_ratio': 1.0, 'content_word_ratio': 0.5, 'sbj_count': 1, 'obj_count': 1, 'advcl_count': 0, 'acl_count': 0, 'conj_count': 0, 'cc_count': 0, 'max_depth': 3, 'avg_dependents': 0.75, 'max_dependents': 2, 'left_deps': 1, 'right_deps': 2, 'left_right_dep_ratio': 0.5, 'total_words': 4}
# أنا أحب أختي

# %% [markdown]
# # Try that on the whole dataset and simple model

# %%
import re
from camel_tools.tokenizers.word import simple_word_tokenize
from camel_tools.utils.dediac import dediac_ar
from camel_tools.utils.normalize import normalize_unicode
from camel_tools.utils.charmap import CharMapper

arclean = CharMapper.builtin_mapper("arclean")

def clean_broken_arabic_words(text):
    """ Clean broken Arabic words and remove tatweel characters."""
    
    def clean_line(line, arclean):
        return simple_word_tokenize(arclean(dediac_ar(normalize_unicode(line.strip()))))
    
    # Step 1: Remove broken words
    text = text.replace(' ـ', '')
    text = text.replace('ـ ', '')

    # use camel tools to clean the text, it removes tatweel characters and diacritics
    text = " ".join(clean_line(text, arclean))
    return text

def clean_sentence(sentence):

    # # Arabic characters range: main + extended + some punctuation
    # arabic_pattern = re.compile(r'[\u0600-\u06FF]+')

    # # Extract all Arabic tokens
    # arabic_tokens = arabic_pattern.findall(sentence)

    # sentence = " ".join(arabic_tokens)
    sentence = clean_broken_arabic_words(sentence)

    # If sentence ends with arabic comma '،', remove it because it mess up with dependency parsing
    if sentence.endswith('،'):
        sentence = sentence[:-1].strip()

    # Remove extra spaces
    sentence = re.sub(r'\s+', ' ', sentence).strip()
        
    # Join with space to reconstruct a clean sentence
    return sentence

def clean_example(example):
    example["Sentence"] = clean_sentence(example["Sentence"])
    return example

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier  # or XGBoost if you want
from sklearn.metrics import classification_report
from datasets import load_dataset
import pyarabic.araby as araby


token = "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"

# Load sentence-level data from the "Dev" split
sent_blind_test = load_dataset("CAMeL-Lab/BAREC-Shared-Task-2025-BlindTest-sent", token=token, split="test")

# Fix labels to be 0-indexed
sent_blind_test = sent_blind_test.map(lambda x: {"Sentence": araby.strip_diacritics(x["Sentence"])})

# we should always clean each sentence in the dataset to be able to join with features
sent_blind_test = sent_blind_test.map(clean_example)

df = pd.DataFrame(sent_blind_test)

# %%
dataset = sent_blind_test
sent_blind_test
# Out:
# Dataset({
#     features: ['ID', 'Sentence', 'Word_Count', 'Annotator', 'Document', 'Source', 'Book', 'Author', 'Domain', 'Text_Class'],
#     num_rows: 3420
# })

# %%
from datasets import Dataset

# Convert to pandas first
df = dataset.to_pandas()

# Drop duplicates by sentence
df_unique = df.drop_duplicates(subset=["Sentence"])

# Convert back to Hugging Face Dataset if needed
dataset = Dataset.from_pandas(df_unique)

# %%
dataset.shape
# Out:
# (3290, 11)

# %%
Split = "blind_testset"

# %%
import os
import math
import numpy as np

N_SPLITS = 10  # Number of chunks
OUTPUT_DIR = "./splits_{}".format(Split)  # Directory to save splits
os.makedirs(OUTPUT_DIR, exist_ok=True)

chunk_size = len(dataset) // N_SPLITS
subsets = []

for i in range(N_SPLITS):
    start = i * chunk_size
    # Make last chunk include all remaining elements
    end = (i + 1) * chunk_size if i < N_SPLITS - 1 else len(dataset)
    subsets.append(dataset.select(range(start, end)))

# Step 2: Process each chunk
N_SPLITS_PER_CHUNK = 1  # Number of sub-chunks per problematic chunk

for i, cleaned_subset in enumerate(subsets):
    subset_len = len(cleaned_subset)
    chunk_size = math.ceil(subset_len / N_SPLITS_PER_CHUNK)

    for j in range(N_SPLITS_PER_CHUNK):
        start_idx = j * chunk_size
        end_idx = min((j + 1) * chunk_size, subset_len)
        sub_chunk = cleaned_subset.select(range(start_idx, end_idx))

        # Save sentences
        input_path = os.path.join(OUTPUT_DIR, f"sentences_{i}_{j+1}.txt")
        with open(input_path, "w", encoding="utf-8") as f:
            for sent in sub_chunk["Sentence"]:
                f.write(sent.strip() + "\n")

        # Run CLI tool
        output_path = os.path.join(OUTPUT_DIR, f"output_{i}_{j+1}.txt")
        os.system(f"python text_to_conll_cli.py -f text -i {input_path} > {output_path}")
# Out:
# #NOAN انتكاسة
# #NOAN وأعراقها
# #NOT_FIRST فإننا
# #NOAN الشكلانية
# #NOT_FIRST وبالتالي
# #NOT_FIRST وبالتالي
# #NOT_FIRST انظر
# #NOAN شمة
# #NOT_FIRST إنجلترا
# #NOT_FIRST إننا
# #NOT_FIRST إن
# #NOT_FIRST إن
# #NOT_FIRST إنني
# #NOT_FIRST إن
# #NOT_FIRST إنني
# #NOT_FIRST إنه
# #NOT_FIRST إنه
# #NOT_FIRST فإن
# #NOAN إيج
# #NOAN إيج
# #NOT_FIRST الوسطى
# #NOAN إيج
# #NOAN إيج
# #NOAN إيج
# #NOT_FIRST الوسطى
# #NOAN إيج
# #NOAN إيج
# #NOT_FIRST بدا
# #NOT_FIRST الوسطى
# #NOT_FIRST فإنهم
# #NOT_FIRST فإن
# #NOT_FIRST فإن
# #NOT_FIRST فإن
# #NOAN الأوزان
# #NOAN الجرمانية
# #NOAN الطورانية
# #NOT_FIRST فإن
# #NOT_FIRST الأعلام
# #NOT_FIRST افتنانا
# #NOAN المعطشة
# #NOT_FIRST الافتنان
# #NOT_FIRST كأحلى
# #NOT_FIRST وإننا
# #NOAN إليجر
# #NOT_FIRST الإنس
# #NOT_FIRST تنتحي
# #NOAN إليجر
# #NOT_FIRST الإنس
# #NOAN إليجر
# #NOAN إليجر
# #NOT_FIRST إنها
# #NOT_FIRST حكي
# #NOT_FIRST بأي
# #NOAN الإدراكية
# #NOAN السردية
# #NOAN إيبنجهاوس
# #NOT_FIRST إن
# #NOT_FIRST إخصائي
# #NOT_FIRST إن
# #NOT_FIRST فإن
# #NOT_FIRST طيلة
# #NOT_FIRST فإننا
# #NOT_FIRST إننا
# #NOT_FIRST فإننا
# #NOT_FIRST آليات
# #NOT_FIRST فإن
# #NOT_FIRST فجأة
# #NOAN أوميارا
# #NOAN تنجيمية
# #NOT_FIRST ألف
# #NOAN البوتسوانية
# #NOT_FIRST ويحتوي
# #NOT_FIRST ألف
# #NOAN لمجرة
# #NOAN مجرة
# #NOT_FIRST فإن
# #NOT_FIRST بدا
# #NOT_FIRST إنها
# #NOAN الهوليودية
# #NOT_FIRST كإفريقيا
# #NOT_FIRST فإن
# #NOT_FIRST إن
# #NOT_FIRST الوسطى
# #NOAN التكتونية
# #NOT_FIRST فإن
# #NOAN آدامز
# #NOT_FIRST إن
# #NOAN ألفرد
# #NOAN أوستفالد
# #NOAN أوستفالد
# #NOAN أوستفالد
# #NOAN أوستفالد
# #NOT_FIRST بني
# #NOAN أودم
# #NOAN أوستفالد
# #NOAN أودم
# #NOT_FIRST الآليات
# #NOAN إريك
# #NOAN أورويل
# /opt/homebrew/anaconda3/envs/camel/lib/python3.9/site-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# INFO:supar.utils.data:Caching the data to /var/folders/dq/xr1b36h54wq7k53g71c_lvnh0000gn/T/tmpplstsndr/data.pt

# %%
def get_each_output_from_file(filepath):
    blocks = []
    current_block = []
    in_block = False

    with open(filepath, encoding="utf-8") as f:
        for line in f:
            line = line.strip()

            # Start of a new block
            if line.startswith("# text = "):
                if current_block:  # Save previous block if one is in progress
                    blocks.append(current_block)
                current_block = [line]
                in_block = True

            # Skip treeTokens lines
            elif line.startswith("# treeTokens"):
                continue

            # Inside a block, add lines until empty line
            elif in_block:
                if line == "":
                    blocks.append(current_block)
                    current_block = []
                    in_block = False
                else:
                    current_block.append(line)

        # Add last block if file doesn’t end with an empty line
        if current_block:
            blocks.append(current_block)

    print(f"Found {len(blocks)} blocks in {filepath}")
    return blocks

all_parsed_blocks = []

# get all files that start with "output_" and end with ".txt"
import os
output_files = [f for f in os.listdir(OUTPUT_DIR) if f.startswith("output_") and f.endswith(".txt")]
for output_file in output_files:
    print(f"Processing {output_file}...")
    filepath = os.path.join(OUTPUT_DIR, output_file)
    blocks = get_each_output_from_file(filepath)
    all_parsed_blocks.extend(blocks)
    
# Now `all_parsed_blocks` contains everything from all output files
print(f"Total parsed blocks: {len(all_parsed_blocks)}")
# Out:
# Processing output_0_1.txt...
# Found 329 blocks in ./splits_blind_testset/output_0_1.txt
# Processing output_2_1.txt...
# Found 329 blocks in ./splits_blind_testset/output_2_1.txt
# Processing output_6_1.txt...
# Found 329 blocks in ./splits_blind_testset/output_6_1.txt
# Processing output_4_1.txt...
# Found 329 blocks in ./splits_blind_testset/output_4_1.txt
# Processing output_3_1.txt...
# Found 329 blocks in ./splits_blind_testset/output_3_1.txt
# Processing output_1_1.txt...
# Found 329 blocks in ./splits_blind_testset/output_1_1.txt
# Processing output_5_1.txt...
# Found 329 blocks in ./splits_blind_testset/output_5_1.txt
# Processing output_7_1.txt...
# Found 329 blocks in ./splits_blind_testset/output_7_1.txt
# Processing output_9_1.txt...
# Found 329 blocks in ./splits_blind_testset/output_9_1.txt
# Processing output_8_1.txt...
# Found 329 blocks in ./splits_blind_testset/output_8_1.txt
# Total parsed blocks: 3290

# %%
# write all_parsed_blocks into a file all_parsed_blocks.txt
with open(f"{OUTPUT_DIR}/all_parsed_blocks_{Split}.txt", "w", encoding="utf-8") as f:
    for block in all_parsed_blocks:
        for line in block:
            f.write(line + "\n")
        f.write("\n")  # Separate blocks with an empty line

# %%
def extract_sentence_from_block(block):
    if block and block[0].startswith("# text ="):
        return block[0].replace("# text = ", "").strip()
    return None

features_list = []
for block in all_parsed_blocks:
    sentence = extract_sentence_from_block(block)
    if sentence is not None:
        feats = extract_features_from_parse(block)
        feats["Sentence"] = sentence  # Clean the sentence to match while joining
        features_list.append(feats)

# write features_list to a file features_list.json, its a list of dicts
import json
with open(f"{OUTPUT_DIR}/features_list_{Split}.json", "w", encoding="utf-8") as f:
    json.dump(features_list, f, ensure_ascii=False, indent=4)
    

features_list
# Out:
# [{'avg_dep_distance': 1.0,
#   'max_dep_distance': 2,
#   'long_deps_count': 0,
#   'noun_count': 5,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.8333333333333334,
#   'sbj_count': 0,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 5,
#   'avg_dependents': 0.8333333333333334,
#   'max_dependents': 2,
#   'left_deps': 0,
#   'right_deps': 5,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 6,
#   'Sentence': 'مجلة كل الأولاد وكل البنات'},
#  {'avg_dep_distance': 0.5,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 1,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 1,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.5,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 2,
#   'avg_dependents': 0.5,
#   'max_dependents': 1,
#   'left_deps': 0,
#   'right_deps': 1,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 2,
#   'Sentence': 'ماجد 2082'},
#  {'avg_dep_distance': 1.4,
#   'max_dep_distance': 4,
#   'long_deps_count': 1,
#   'noun_count': 3,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 2,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.6,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 4,
#   'avg_dependents': 0.8,
#   'max_dependents': 2,
#   'left_deps': 0,
#   'right_deps': 4,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 5,
#   'Sentence': 'الأربعاء 16 يناير 2019 م'},
#  {'avg_dep_distance': 1.0,
#   'max_dep_distance': 2,
#   'long_deps_count': 0,
#   'noun_count': 2,
#   'verb_count': 0,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 2,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.6,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 4,
#   'avg_dependents': 0.8,
#   'max_dependents': 2,
#   'left_deps': 0,
#   'right_deps': 4,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 5,
#   'Sentence': '10 جمادى الأولى 1440 ه'},
#  {'avg_dep_distance': 0.5,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 1,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 1,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.5,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 2,
#   'avg_dependents': 0.5,
#   'max_dependents': 1,
#   'left_deps': 0,
#   'right_deps': 1,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 2,
#   'Sentence': 'السنة الأربعون'},
#  {'avg_dep_distance': 0.6666666666666666,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 2,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 1,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.6666666666666666,
#   'sbj_count': 1,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 2,
#   'avg_dependents': 0.6666666666666666,
#   'max_dependents': 2,
#   'left_deps': 1,
#   'right_deps': 1,
#   'left_right_dep_ratio': 1.0,
#   'total_words': 3,
#   'Sentence': 'الثمن 5 دراهم'},
#  {'avg_dep_distance': 0.75,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 4,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 1.0,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 3,
#   'avg_dependents': 0.75,
#   'max_dependents': 2,
#   'left_deps': 1,
#   'right_deps': 2,
#   'left_right_dep_ratio': 0.5,
#   'total_words': 4,
#   'Sentence': 'بوستر هدية داخل العدد'},
#  {'avg_dep_distance': 0.0,
#   'max_dep_distance': 0,
#   'long_deps_count': 0,
#   'noun_count': 0,
#   'verb_count': 1,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0,
#   'content_word_ratio': 1.0,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 1,
#   'avg_dependents': 0.0,
#   'max_dependents': 0,
#   'left_deps': 0,
#   'right_deps': 0,
#   'left_right_dep_ratio': 0,
#   'total_words': 1,
#   'Sentence': 'فكر'},
#  {'avg_dep_distance': 0.0,
#   'max_dep_distance': 0,
#   'long_deps_count': 0,
#   'noun_count': 0,
#   'verb_count': 1,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0,
#   'content_word_ratio': 1.0,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 1,
#   'avg_dependents': 0.0,
#   'max_dependents': 0,
#   'left_deps': 0,
#   'right_deps': 0,
#   'left_right_dep_ratio': 0,
#   'total_words': 1,
#   'Sentence': 'أبدع'},
#  {'avg_dep_distance': 0.0,
#   'max_dep_distance': 0,
#   'long_deps_count': 0,
#   'noun_count': 0,
#   'verb_count': 1,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0,
#   'content_word_ratio': 1.0,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 1,
#   'avg_dependents': 0.0,
#   'max_dependents': 0,
#   'left_deps': 0,
#   'right_deps': 0,
#   'left_right_dep_ratio': 0,
#   'total_words': 1,
#   'Sentence': 'ابتكر'},
#  {'avg_dep_distance': 0.6666666666666666,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 2,
#   'verb_count': 0,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 1.0,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 3,
#   'avg_dependents': 0.6666666666666666,
#   'max_dependents': 1,
#   'left_deps': 0,
#   'right_deps': 2,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 3,
#   'Sentence': 'مشروع عيون منيرة'},
#  {'avg_dep_distance': 7.103448275862069,
#   'max_dep_distance': 115,
#   'long_deps_count': 35,
#   'noun_count': 50,
#   'verb_count': 0,
#   'adj_count': 4,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 31,
#   'punct_count': 31,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.46551724137931033,
#   'sbj_count': 0,
#   'obj_count': 2,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 11,
#   'avg_dependents': 0.9913793103448276,
#   'max_dependents': 10,
#   'left_deps': 5,
#   'right_deps': 110,
#   'left_right_dep_ratio': 0.045454545454545456,
#   'total_words': 116,
#   'Sentence': 'السعودية 5 ريالات - البحرين 500 فلس - الكويت 400 فلس - سلطنة عمان 500 بيسة - لبنان 1500 ليرة - المغرب 8 دراهم - الجزائر 120 دينارا - الأردن 800 فلس - تونس 1 . 5 دينار - مصر 5 جنيهات - ليبيا 1 . 5 دينار - الجمهورية اليمنية 220 ريالا - سوريا 550 ليرة - العراق 1 دولار - السودان 3 جنيهات - فرنسا 0 . 75 يورو - إنجلترا جنيه واحد - الولايات المتحدة 2 دولار - كندا 2 . 5 دولار - سويسرا 4 فرنكات - اليونان 0 . 5 يورو - قبرص 1 . 75 يورو - الهند 15 روبية - باكستان 75 روبية - تايلاند 5 دولار أمريكي .'},
#  {'avg_dep_distance': 1.5555555555555556,
#   'max_dep_distance': 7,
#   'long_deps_count': 1,
#   'noun_count': 5,
#   'verb_count': 1,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 1,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.2,
#   'content_word_ratio': 0.6666666666666666,
#   'sbj_count': 0,
#   'obj_count': 2,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 7,
#   'avg_dependents': 0.8888888888888888,
#   'max_dependents': 3,
#   'left_deps': 1,
#   'right_deps': 7,
#   'left_right_dep_ratio': 0.14285714285714285,
#   'total_words': 9,
#   'Sentence': 'هل تريدون الانضمام لفريق إعداد مجلة ماجد ?'},
#  {'avg_dep_distance': 0.5,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 0,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 1,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0,
#   'content_word_ratio': 0.5,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 2,
#   'avg_dependents': 0.5,
#   'max_dependents': 1,
#   'left_deps': 0,
#   'right_deps': 1,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 2,
#   'Sentence': 'كيف ?'},
#  {'avg_dep_distance': 0.6666666666666666,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 2,
#   'verb_count': 1,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.5,
#   'content_word_ratio': 1.0,
#   'sbj_count': 1,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 2,
#   'avg_dependents': 0.6666666666666666,
#   'max_dependents': 2,
#   'left_deps': 1,
#   'right_deps': 1,
#   'left_right_dep_ratio': 1.0,
#   'total_words': 3,
#   'Sentence': 'تعالوا نستعرض الخطوات'},
#  {'avg_dep_distance': 1.4090909090909092,
#   'max_dep_distance': 3,
#   'long_deps_count': 0,
#   'noun_count': 9,
#   'verb_count': 4,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 3,
#   'cconj_count': 3,
#   'num_count': 1,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.4444444444444444,
#   'content_word_ratio': 0.6363636363636364,
#   'sbj_count': 0,
#   'obj_count': 8,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 12,
#   'avg_dependents': 0.9545454545454546,
#   'max_dependents': 3,
#   'left_deps': 1,
#   'right_deps': 20,
#   'left_right_dep_ratio': 0.05,
#   'total_words': 22,
#   'Sentence': '1 تجدون داخل المجلة استمارة المشاركة : اكتبوا مقالا أعجبكم أو قصة قصيرة أو حكمة ألهمتكم أو نكتة أضحكتكم'},
#  {'avg_dep_distance': 1.7058823529411764,
#   'max_dep_distance': 8,
#   'long_deps_count': 1,
#   'noun_count': 4,
#   'verb_count': 3,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 3,
#   'pron_count': 4,
#   'cconj_count': 1,
#   'num_count': 1,
#   'punct_count': 0,
#   'sconj_count': 1,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.75,
#   'content_word_ratio': 0.4117647058823529,
#   'sbj_count': 0,
#   'obj_count': 8,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 6,
#   'avg_dependents': 0.9411764705882353,
#   'max_dependents': 4,
#   'left_deps': 3,
#   'right_deps': 13,
#   'left_right_dep_ratio': 0.23076923076923078,
#   'total_words': 17,
#   'Sentence': '2 سجلوا بياناتكم بوضوح وإن رغبتم ضعوا صوركم لننشرها لكم'},
#  {'avg_dep_distance': 2.1739130434782608,
#   'max_dep_distance': 9,
#   'long_deps_count': 4,
#   'noun_count': 9,
#   'verb_count': 1,
#   'adj_count': 3,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 2,
#   'cconj_count': 1,
#   'num_count': 2,
#   'punct_count': 3,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.1111111111111111,
#   'content_word_ratio': 0.5652173913043478,
#   'sbj_count': 0,
#   'obj_count': 4,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 9,
#   'avg_dependents': 0.9565217391304348,
#   'max_dependents': 6,
#   'left_deps': 2,
#   'right_deps': 20,
#   'left_right_dep_ratio': 0.1,
#   'total_words': 23,
#   'Sentence': '3 الآن اطووا المغلف وأرسلوه لنا على العنوان التالي : الإمارات العربية المتحدة - أبو ظبي ص . ب 3558'},
#  {'avg_dep_distance': 2.142857142857143,
#   'max_dep_distance': 11,
#   'long_deps_count': 2,
#   'noun_count': 2,
#   'verb_count': 2,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 2,
#   'cconj_count': 2,
#   'num_count': 1,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 1.0,
#   'content_word_ratio': 0.35714285714285715,
#   'sbj_count': 0,
#   'obj_count': 5,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 6,
#   'avg_dependents': 0.9285714285714286,
#   'max_dependents': 5,
#   'left_deps': 2,
#   'right_deps': 11,
#   'left_right_dep_ratio': 0.18181818181818182,
#   'total_words': 14,
#   'Sentence': '4 أو صوروا الاستمارة وأرسلوها لنا على البريد الإلكتروني Majid .'},
#  {'avg_dep_distance': 2.4285714285714284,
#   'max_dep_distance': 7,
#   'long_deps_count': 4,
#   'noun_count': 4,
#   'verb_count': 2,
#   'adj_count': 0,
#   'adv_count': 1,
#   'adp_count': 1,
#   'pron_count': 2,
#   'cconj_count': 0,
#   'num_count': 1,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 1,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.5,
#   'content_word_ratio': 0.5,
#   'sbj_count': 0,
#   'obj_count': 3,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 5,
#   'avg_dependents': 0.9285714285714286,
#   'max_dependents': 7,
#   'left_deps': 3,
#   'right_deps': 10,
#   'left_right_dep_ratio': 0.3,
#   'total_words': 14,
#   'Sentence': '5 فور استلامنا مشاركتكم سنقرأ باهتمام . . ثم نعتمد'},
#  {'avg_dep_distance': 1.3333333333333333,
#   'max_dep_distance': 4,
#   'long_deps_count': 1,
#   'noun_count': 6,
#   'verb_count': 2,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 1,
#   'cconj_count': 1,
#   'num_count': 1,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 1,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.3333333333333333,
#   'content_word_ratio': 0.6,
#   'sbj_count': 1,
#   'obj_count': 3,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 8,
#   'avg_dependents': 0.9333333333333333,
#   'max_dependents': 4,
#   'left_deps': 2,
#   'right_deps': 12,
#   'left_right_dep_ratio': 0.16666666666666666,
#   'total_words': 15,
#   'Sentence': '6 سيعمل أمهر رسامي المجلة على دعم كتابكم برسوم جميلة ومعبرة'},
#  {'avg_dep_distance': 1.8,
#   'max_dep_distance': 7,
#   'long_deps_count': 1,
#   'noun_count': 4,
#   'verb_count': 2,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 3,
#   'cconj_count': 1,
#   'num_count': 1,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 1,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.5,
#   'content_word_ratio': 0.4666666666666667,
#   'sbj_count': 2,
#   'obj_count': 3,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 5,
#   'avg_dependents': 0.9333333333333333,
#   'max_dependents': 6,
#   'left_deps': 3,
#   'right_deps': 11,
#   'left_right_dep_ratio': 0.2727272727272727,
#   'total_words': 15,
#   'Sentence': 'والآن ستنشر مشاركتكم في مكانها المناسب ليقرأها آلاف الأصدقاء'},
#  {'avg_dep_distance': 1.5,
#   'max_dep_distance': 3,
#   'long_deps_count': 0,
#   'noun_count': 1,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 1,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.25,
#   'sbj_count': 0,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 3,
#   'avg_dependents': 0.75,
#   'max_dependents': 2,
#   'left_deps': 1,
#   'right_deps': 2,
#   'left_right_dep_ratio': 0.5,
#   'total_words': 4,
#   'Sentence': 'في هذا العدد :'},
#  {'avg_dep_distance': 1.75,
#   'max_dep_distance': 4,
#   'long_deps_count': 1,
#   'noun_count': 4,
#   'verb_count': 0,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 1,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.625,
#   'sbj_count': 1,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 4,
#   'avg_dependents': 0.875,
#   'max_dependents': 4,
#   'left_deps': 2,
#   'right_deps': 5,
#   'left_right_dep_ratio': 0.4,
#   'total_words': 8,
#   'Sentence': '6 طريق ثراء الثعلب محفوف بالبيض !'},
#  {'avg_dep_distance': 1.875,
#   'max_dep_distance': 5,
#   'long_deps_count': 1,
#   'noun_count': 1,
#   'verb_count': 1,
#   'adj_count': 2,
#   'adv_count': 1,
#   'adp_count': 1,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 1,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 1.0,
#   'content_word_ratio': 0.625,
#   'sbj_count': 1,
#   'obj_count': 2,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 3,
#   'avg_dependents': 0.875,
#   'max_dependents': 6,
#   'left_deps': 2,
#   'right_deps': 5,
#   'left_right_dep_ratio': 0.4,
#   'total_words': 8,
#   'Sentence': '18 لماذا قدم الفضائي حبتين لكسلان ?'},
#  {'avg_dep_distance': 1.4285714285714286,
#   'max_dep_distance': 4,
#   'long_deps_count': 1,
#   'noun_count': 1,
#   'verb_count': 1,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 1,
#   'cconj_count': 0,
#   'num_count': 1,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 1.0,
#   'content_word_ratio': 0.42857142857142855,
#   'sbj_count': 0,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 4,
#   'avg_dependents': 0.8571428571428571,
#   'max_dependents': 4,
#   'left_deps': 2,
#   'right_deps': 4,
#   'left_right_dep_ratio': 0.5,
#   'total_words': 7,
#   'Sentence': '26 ماذا تعرف عن الفضول الإيجابي ?'},
#  {'avg_dep_distance': 1.0,
#   'max_dep_distance': 2,
#   'long_deps_count': 0,
#   'noun_count': 0,
#   'verb_count': 2,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 1,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0,
#   'content_word_ratio': 0.5,
#   'sbj_count': 0,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 4,
#   'avg_dependents': 0.75,
#   'max_dependents': 1,
#   'left_deps': 1,
#   'right_deps': 2,
#   'left_right_dep_ratio': 0.5,
#   'total_words': 4,
#   'Sentence': 'ابتكر ولا تقلد'},
#  {'avg_dep_distance': 1.6923076923076923,
#   'max_dep_distance': 8,
#   'long_deps_count': 2,
#   'noun_count': 3,
#   'verb_count': 2,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 2,
#   'cconj_count': 2,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 1,
#   'part_count': 1,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.6666666666666666,
#   'content_word_ratio': 0.38461538461538464,
#   'sbj_count': 1,
#   'obj_count': 5,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 8,
#   'avg_dependents': 0.9230769230769231,
#   'max_dependents': 4,
#   'left_deps': 2,
#   'right_deps': 10,
#   'left_right_dep_ratio': 0.2,
#   'total_words': 13,
#   'Sentence': 'من منكم لا يريد أن يكون مبتكرا أو مستكشفا أو مخترعا ?'},
#  {'avg_dep_distance': 2.5294117647058822,
#   'max_dep_distance': 33,
#   'long_deps_count': 5,
#   'noun_count': 12,
#   'verb_count': 2,
#   'adj_count': 2,
#   'adv_count': 0,
#   'adp_count': 5,
#   'pron_count': 6,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 2,
#   'part_count': 2,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.16666666666666666,
#   'content_word_ratio': 0.47058823529411764,
#   'sbj_count': 3,
#   'obj_count': 8,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 18,
#   'avg_dependents': 0.9705882352941176,
#   'max_dependents': 4,
#   'left_deps': 1,
#   'right_deps': 32,
#   'left_right_dep_ratio': 0.03125,
#   'total_words': 34,
#   'Sentence': 'اعلموا يا أحبائي أن كلا منا لديه رغبة بأن يكون الأسبق في تقديم شيء جديد , أو اكتشاف أمر لم يعلم به أحد من أصدقائه قبله .'},
#  {'avg_dep_distance': 2.5,
#   'max_dep_distance': 15,
#   'long_deps_count': 2,
#   'noun_count': 6,
#   'verb_count': 1,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 3,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 1,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.16666666666666666,
#   'content_word_ratio': 0.5,
#   'sbj_count': 1,
#   'obj_count': 5,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 7,
#   'avg_dependents': 0.9375,
#   'max_dependents': 3,
#   'left_deps': 1,
#   'right_deps': 14,
#   'left_right_dep_ratio': 0.07142857142857142,
#   'total_words': 16,
#   'Sentence': 'في هذا الأمر شعور جميل جدا يجعل والدينا وأساتذتنا فخورين بنا .'},
#  {'avg_dep_distance': 3.0,
#   'max_dep_distance': 25,
#   'long_deps_count': 6,
#   'noun_count': 6,
#   'verb_count': 6,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 6,
#   'pron_count': 3,
#   'cconj_count': 5,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 3,
#   'part_count': 0,
#   'det_count': 1,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 1.0,
#   'content_word_ratio': 0.3939393939393939,
#   'sbj_count': 1,
#   'obj_count': 14,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 11,
#   'avg_dependents': 0.9696969696969697,
#   'max_dependents': 5,
#   'left_deps': 2,
#   'right_deps': 30,
#   'left_right_dep_ratio': 0.06666666666666667,
#   'total_words': 33,
#   'Sentence': 'ولكي نتمكن من تحقيق ذلك علينا أن نجرب ونتعلم ونطلع على إنجازات الآخرين ونثني عليها , وأن نعطي صاحب السبق حقه في التقدير .'},
#  {'avg_dep_distance': 2.235294117647059,
#   'max_dep_distance': 13,
#   'long_deps_count': 2,
#   'noun_count': 7,
#   'verb_count': 2,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 4,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 1,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.2857142857142857,
#   'content_word_ratio': 0.5294117647058824,
#   'sbj_count': 1,
#   'obj_count': 4,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 7,
#   'avg_dependents': 0.9411764705882353,
#   'max_dependents': 4,
#   'left_deps': 2,
#   'right_deps': 14,
#   'left_right_dep_ratio': 0.14285714285714285,
#   'total_words': 17,
#   'Sentence': 'في هذا العدد أهديكم لعبة مبتكرة صنعها لكم أحبائي فريق مجلة ماجد ,'},
#  {'avg_dep_distance': 3.4444444444444446,
#   'max_dep_distance': 24,
#   'long_deps_count': 6,
#   'noun_count': 8,
#   'verb_count': 2,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 7,
#   'cconj_count': 4,
#   'num_count': 0,
#   'punct_count': 3,
#   'sconj_count': 1,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 1,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.25,
#   'content_word_ratio': 0.37037037037037035,
#   'sbj_count': 2,
#   'obj_count': 5,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 6,
#   'avg_dependents': 0.9629629629629629,
#   'max_dependents': 7,
#   'left_deps': 4,
#   'right_deps': 22,
#   'left_right_dep_ratio': 0.18181818181818182,
#   'total_words': 27,
#   'Sentence': 'العبوها مع والديكم وإخوانكم وأصدقائكم , وأنا متأكد أنها ستفيدكم جدا , وستمتعكم أيضا .'},
#  {'avg_dep_distance': 2.923076923076923,
#   'max_dep_distance': 38,
#   'long_deps_count': 6,
#   'noun_count': 11,
#   'verb_count': 7,
#   'adj_count': 2,
#   'adv_count': 0,
#   'adp_count': 4,
#   'pron_count': 7,
#   'cconj_count': 3,
#   'num_count': 0,
#   'punct_count': 3,
#   'sconj_count': 1,
#   'part_count': 0,
#   'det_count': 1,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.6363636363636364,
#   'content_word_ratio': 0.5128205128205128,
#   'sbj_count': 1,
#   'obj_count': 15,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 16,
#   'avg_dependents': 0.9743589743589743,
#   'max_dependents': 5,
#   'left_deps': 1,
#   'right_deps': 37,
#   'left_right_dep_ratio': 0.02702702702702703,
#   'total_words': 39,
#   'Sentence': 'أدعوكم أصدقائي من خلال هذا العدد أن تنموا مهاراتكم , وتبحثوا عن المغامر الصغير فيكم , وتتركوا الألعاب الجاهزة لتبتكروا ألعابكم الخاصة التي تجعل أوقاتكم أكثر متعة وفائدة .'},
#  {'avg_dep_distance': 3.142857142857143,
#   'max_dep_distance': 27,
#   'long_deps_count': 4,
#   'noun_count': 11,
#   'verb_count': 3,
#   'adj_count': 2,
#   'adv_count': 0,
#   'adp_count': 3,
#   'pron_count': 4,
#   'cconj_count': 2,
#   'num_count': 0,
#   'punct_count': 3,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.2727272727272727,
#   'content_word_ratio': 0.5714285714285714,
#   'sbj_count': 1,
#   'obj_count': 9,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 11,
#   'avg_dependents': 0.9642857142857143,
#   'max_dependents': 5,
#   'left_deps': 1,
#   'right_deps': 26,
#   'left_right_dep_ratio': 0.038461538461538464,
#   'total_words': 28,
#   'Sentence': 'يمكنكم أحبائي مسح الكود المرفق وطباعة " البوستر " وإرساله لأكبر عدد من أصدقائكم ليشاركوا معكم ابتكار ماجد الخاص .'},
#  {'avg_dep_distance': 0.6666666666666666,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 2,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 1,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.6666666666666666,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 3,
#   'avg_dependents': 0.6666666666666666,
#   'max_dependents': 1,
#   'left_deps': 0,
#   'right_deps': 2,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 3,
#   'Sentence': 'مع محبتي'},
#  {'avg_dep_distance': 0.0,
#   'max_dep_distance': 0,
#   'long_deps_count': 0,
#   'noun_count': 1,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 1.0,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 1,
#   'avg_dependents': 0.0,
#   'max_dependents': 0,
#   'left_deps': 0,
#   'right_deps': 0,
#   'left_right_dep_ratio': 0,
#   'total_words': 1,
#   'Sentence': 'ماجد'},
#  {'avg_dep_distance': 1.7142857142857142,
#   'max_dep_distance': 4,
#   'long_deps_count': 1,
#   'noun_count': 2,
#   'verb_count': 1,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 1,
#   'cconj_count': 0,
#   'num_count': 1,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.5,
#   'content_word_ratio': 0.5714285714285714,
#   'sbj_count': 1,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 5,
#   'avg_dependents': 0.8571428571428571,
#   'max_dependents': 3,
#   'left_deps': 1,
#   'right_deps': 5,
#   'left_right_dep_ratio': 0.2,
#   'total_words': 7,
#   'Sentence': '42 ذاكرة أبو الظرفاء تخونه !'},
#  {'avg_dep_distance': 1.4,
#   'max_dep_distance': 3,
#   'long_deps_count': 0,
#   'noun_count': 3,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 1,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.6,
#   'sbj_count': 1,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 4,
#   'avg_dependents': 0.8,
#   'max_dependents': 2,
#   'left_deps': 1,
#   'right_deps': 3,
#   'left_right_dep_ratio': 0.3333333333333333,
#   'total_words': 5,
#   'Sentence': '52 الخال عامر في ورطة'},
#  {'avg_dep_distance': 1.0,
#   'max_dep_distance': 2,
#   'long_deps_count': 0,
#   'noun_count': 3,
#   'verb_count': 1,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 1,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.3333333333333333,
#   'content_word_ratio': 0.7142857142857143,
#   'sbj_count': 0,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 6,
#   'avg_dependents': 0.8571428571428571,
#   'max_dependents': 2,
#   'left_deps': 0,
#   'right_deps': 6,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 7,
#   'Sentence': '50 كراملة تساعدنا في اختيار الوجبة الخفيفة'},
#  {'avg_dep_distance': 1.8571428571428572,
#   'max_dep_distance': 5,
#   'long_deps_count': 2,
#   'noun_count': 3,
#   'verb_count': 1,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 1,
#   'cconj_count': 0,
#   'num_count': 1,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.3333333333333333,
#   'content_word_ratio': 0.5714285714285714,
#   'sbj_count': 1,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 5,
#   'avg_dependents': 0.8571428571428571,
#   'max_dependents': 3,
#   'left_deps': 2,
#   'right_deps': 4,
#   'left_right_dep_ratio': 0.5,
#   'total_words': 7,
#   'Sentence': '44 من سرق حقيبة الجدة اعتدال ?'},
#  {'avg_dep_distance': 0.6666666666666666,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 1,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.3333333333333333,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 3,
#   'avg_dependents': 0.6666666666666666,
#   'max_dependents': 1,
#   'left_deps': 0,
#   'right_deps': 2,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 3,
#   'Sentence': 'التسامح . .'},
#  {'avg_dep_distance': 0.6666666666666666,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 2,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.6666666666666666,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 2,
#   'avg_dependents': 0.6666666666666666,
#   'max_dependents': 2,
#   'left_deps': 1,
#   'right_deps': 1,
#   'left_right_dep_ratio': 1.0,
#   'total_words': 3,
#   'Sentence': '- منهج زايد'},
#  {'avg_dep_distance': 2.5238095238095237,
#   'max_dep_distance': 11,
#   'long_deps_count': 4,
#   'noun_count': 8,
#   'verb_count': 1,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 0,
#   'cconj_count': 5,
#   'num_count': 0,
#   'punct_count': 4,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.125,
#   'content_word_ratio': 0.47619047619047616,
#   'sbj_count': 0,
#   'obj_count': 8,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 7,
#   'avg_dependents': 0.9523809523809523,
#   'max_dependents': 3,
#   'left_deps': 1,
#   'right_deps': 19,
#   'left_right_dep_ratio': 0.05263157894736842,
#   'total_words': 21,
#   'Sentence': 'في المدرسة , والحديقة , والشارع , تشاهدون أطفالا ونساء ورجالا من بلدان وأديان مختلفة .'},
#  {'avg_dep_distance': 2.090909090909091,
#   'max_dep_distance': 8,
#   'long_deps_count': 2,
#   'noun_count': 4,
#   'verb_count': 1,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 1,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.25,
#   'content_word_ratio': 0.45454545454545453,
#   'sbj_count': 1,
#   'obj_count': 3,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 5,
#   'avg_dependents': 0.9090909090909091,
#   'max_dependents': 5,
#   'left_deps': 1,
#   'right_deps': 9,
#   'left_right_dep_ratio': 0.1111111111111111,
#   'total_words': 11,
#   'Sentence': 'كلهم يعيشون في الإمارات , بمودة وسلام .'},
#  {'avg_dep_distance': 1.3333333333333333,
#   'max_dep_distance': 4,
#   'long_deps_count': 1,
#   'noun_count': 3,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 1,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.5,
#   'sbj_count': 1,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 4,
#   'avg_dependents': 0.8333333333333334,
#   'max_dependents': 3,
#   'left_deps': 1,
#   'right_deps': 4,
#   'left_right_dep_ratio': 0.25,
#   'total_words': 6,
#   'Sentence': 'هذا شكل من أشكال التسامح .'},
#  {'avg_dep_distance': 2.769230769230769,
#   'max_dep_distance': 22,
#   'long_deps_count': 5,
#   'noun_count': 7,
#   'verb_count': 2,
#   'adj_count': 2,
#   'adv_count': 0,
#   'adp_count': 3,
#   'pron_count': 4,
#   'cconj_count': 3,
#   'num_count': 0,
#   'punct_count': 3,
#   'sconj_count': 1,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.2857142857142857,
#   'content_word_ratio': 0.4230769230769231,
#   'sbj_count': 2,
#   'obj_count': 8,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 11,
#   'avg_dependents': 0.9615384615384616,
#   'max_dependents': 4,
#   'left_deps': 2,
#   'right_deps': 23,
#   'left_right_dep_ratio': 0.08695652173913043,
#   'total_words': 26,
#   'Sentence': 'ومعناه أن يقبل الناس بعضهم بعضا , ويحترمون الأديان المختلفة عن دينهم , والثقافة المختلفة عن ثقافتهم .'},
#  {'avg_dep_distance': 3.1714285714285713,
#   'max_dep_distance': 33,
#   'long_deps_count': 7,
#   'noun_count': 12,
#   'verb_count': 6,
#   'adj_count': 2,
#   'adv_count': 0,
#   'adp_count': 3,
#   'pron_count': 4,
#   'cconj_count': 2,
#   'num_count': 0,
#   'punct_count': 5,
#   'sconj_count': 1,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.5,
#   'content_word_ratio': 0.5714285714285714,
#   'sbj_count': 4,
#   'obj_count': 7,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 9,
#   'avg_dependents': 0.9714285714285714,
#   'max_dependents': 4,
#   'left_deps': 2,
#   'right_deps': 32,
#   'left_right_dep_ratio': 0.0625,
#   'total_words': 35,
#   'Sentence': 'وكان المغفور له الشيخ زايد بن سلطان آل نهيان ( طيب الله ثراه ) يؤمن أن التسامح يجعل المجتمع قويا , يكثر فيه الخير , ويقل فيه الشر .'},
#  {'avg_dep_distance': 2.2222222222222223,
#   'max_dep_distance': 8,
#   'long_deps_count': 2,
#   'noun_count': 2,
#   'verb_count': 2,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 0,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 1.0,
#   'content_word_ratio': 0.4444444444444444,
#   'sbj_count': 0,
#   'obj_count': 3,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 5,
#   'avg_dependents': 0.8888888888888888,
#   'max_dependents': 4,
#   'left_deps': 0,
#   'right_deps': 8,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 9,
#   'Sentence': 'يقترب من الحب , ويبتعد عن الكراهية .'},
#  {'avg_dep_distance': 2.1538461538461537,
#   'max_dep_distance': 11,
#   'long_deps_count': 1,
#   'noun_count': 2,
#   'verb_count': 2,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 2,
#   'cconj_count': 2,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 2,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 1.0,
#   'content_word_ratio': 0.3076923076923077,
#   'sbj_count': 1,
#   'obj_count': 3,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 5,
#   'avg_dependents': 0.9230769230769231,
#   'max_dependents': 4,
#   'left_deps': 3,
#   'right_deps': 9,
#   'left_right_dep_ratio': 0.3333333333333333,
#   'total_words': 13,
#   'Sentence': '" إنني لا أنفرد برأي ولا أفرضه فرضا ,'},
#  {'avg_dep_distance': 2.5,
#   'max_dep_distance': 10,
#   'long_deps_count': 5,
#   'noun_count': 4,
#   'verb_count': 3,
#   'adj_count': 2,
#   'adv_count': 1,
#   'adp_count': 3,
#   'pron_count': 2,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 3,
#   'sconj_count': 2,
#   'part_count': 0,
#   'det_count': 1,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.75,
#   'content_word_ratio': 0.45454545454545453,
#   'sbj_count': 3,
#   'obj_count': 4,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 8,
#   'avg_dependents': 0.9545454545454546,
#   'max_dependents': 5,
#   'left_deps': 3,
#   'right_deps': 18,
#   'left_right_dep_ratio': 0.16666666666666666,
#   'total_words': 22,
#   'Sentence': 'وإذا كانت هناك آراء مخالفة لرأيي , عدلت إلى الرأي الأصوب , لأنني أعتبر هذا فضيلة "'},
#  {'avg_dep_distance': 0.875,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 7,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.875,
#   'sbj_count': 0,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 8,
#   'avg_dependents': 0.875,
#   'max_dependents': 1,
#   'left_deps': 0,
#   'right_deps': 7,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 8,
#   'Sentence': 'من أقوال الشيخ زايد بن سلطان آل نهيان'},
#  {'avg_dep_distance': 1.9090909090909092,
#   'max_dep_distance': 7,
#   'long_deps_count': 1,
#   'noun_count': 4,
#   'verb_count': 1,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 3,
#   'pron_count': 0,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 1,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.25,
#   'content_word_ratio': 0.45454545454545453,
#   'sbj_count': 0,
#   'obj_count': 4,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 5,
#   'avg_dependents': 0.9090909090909091,
#   'max_dependents': 5,
#   'left_deps': 2,
#   'right_deps': 8,
#   'left_right_dep_ratio': 0.25,
#   'total_words': 11,
#   'Sentence': 'ولذلك تجدون في الإمارات المساجد إلى جانب الكنائس .'},
#  {'avg_dep_distance': 2.9545454545454546,
#   'max_dep_distance': 20,
#   'long_deps_count': 5,
#   'noun_count': 4,
#   'verb_count': 3,
#   'adj_count': 3,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 4,
#   'cconj_count': 4,
#   'num_count': 0,
#   'punct_count': 4,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.75,
#   'content_word_ratio': 0.45454545454545453,
#   'sbj_count': 0,
#   'obj_count': 6,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 9,
#   'avg_dependents': 0.9545454545454546,
#   'max_dependents': 5,
#   'left_deps': 1,
#   'right_deps': 20,
#   'left_right_dep_ratio': 0.05,
#   'total_words': 22,
#   'Sentence': 'وتصادفون من يتحدث اللغة العربية مثلكم , ومن يتحدث اللغة الإنجليزية , أو الفرنسية , وغيرهما .'},
#  {'avg_dep_distance': 2.7857142857142856,
#   'max_dep_distance': 40,
#   'long_deps_count': 8,
#   'noun_count': 13,
#   'verb_count': 5,
#   'adj_count': 3,
#   'adv_count': 0,
#   'adp_count': 6,
#   'pron_count': 5,
#   'cconj_count': 2,
#   'num_count': 0,
#   'punct_count': 4,
#   'sconj_count': 3,
#   'part_count': 1,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.38461538461538464,
#   'content_word_ratio': 0.5,
#   'sbj_count': 3,
#   'obj_count': 10,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 15,
#   'avg_dependents': 0.9761904761904762,
#   'max_dependents': 4,
#   'left_deps': 1,
#   'right_deps': 40,
#   'left_right_dep_ratio': 0.025,
#   'total_words': 42,
#   'Sentence': 'وكان رحمه الله يعتبر أن التسامح مع الآراء المختلفة عن آرائنا واجب علينا جميعا , لأن لا أحد يمتلك الصواب كاملا , ولأن اختلاف وجهات النظر من مصلحة المجتمع , الذي نعيش فيه .'},
#  {'avg_dep_distance': 0.5,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 2,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 1.0,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 2,
#   'avg_dependents': 0.5,
#   'max_dependents': 1,
#   'left_deps': 0,
#   'right_deps': 1,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 2,
#   'Sentence': 'غابة الحكايات'},
#  {'avg_dep_distance': 0.5,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 1,
#   'verb_count': 0,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 1.0,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 2,
#   'avg_dependents': 0.5,
#   'max_dependents': 1,
#   'left_deps': 0,
#   'right_deps': 1,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 2,
#   'Sentence': 'الحلم الضائع'},
#  {'avg_dep_distance': 1.5714285714285714,
#   'max_dep_distance': 4,
#   'long_deps_count': 1,
#   'noun_count': 5,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.7142857142857143,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 3,
#   'avg_dependents': 0.8571428571428571,
#   'max_dependents': 3,
#   'left_deps': 0,
#   'right_deps': 6,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 7,
#   'Sentence': 'سيناريو : مجدي مصطفى رسوم : حجاج'},
#  {'avg_dep_distance': 2.6923076923076925,
#   'max_dep_distance': 9,
#   'long_deps_count': 2,
#   'noun_count': 7,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 2,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 3,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.5384615384615384,
#   'sbj_count': 2,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 5,
#   'avg_dependents': 0.9230769230769231,
#   'max_dependents': 6,
#   'left_deps': 2,
#   'right_deps': 10,
#   'left_right_dep_ratio': 0.2,
#   'total_words': 13,
#   'Sentence': 'مغامرات مسرحها أرض الغابة , وأبطالها سكان الغابة . .'},
#  {'avg_dep_distance': 3.782608695652174,
#   'max_dep_distance': 22,
#   'long_deps_count': 5,
#   'noun_count': 11,
#   'verb_count': 2,
#   'adj_count': 2,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 0,
#   'cconj_count': 4,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.18181818181818182,
#   'content_word_ratio': 0.6521739130434783,
#   'sbj_count': 2,
#   'obj_count': 6,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 7,
#   'avg_dependents': 0.9565217391304348,
#   'max_dependents': 6,
#   'left_deps': 0,
#   'right_deps': 22,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 23,
#   'Sentence': 'تجمع بين الفكاهة والتشويق في النفوس حب التعاون وقيمة العمل ومساعدة الآخرين , وتكون الغلبة دائما للخير .'},
#  {'avg_dep_distance': 0.75,
#   'max_dep_distance': 1,
#   'long_deps_count': 0,
#   'noun_count': 0,
#   'verb_count': 2,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 0,
#   'sconj_count': 1,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
# ...
#   'obj_count': 4,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 7,
#   'avg_dependents': 0.9545454545454546,
#   'max_dependents': 5,
#   'left_deps': 2,
#   'right_deps': 19,
#   'left_right_dep_ratio': 0.10526315789473684,
#   'total_words': 22,
#   'Sentence': 'المشكلات المتوسطة : هي المشكلات التي لها حل واحد , ولكن يمكن الوصول إلى هذا الحل بطرائق مختلفة .'},
#  {'avg_dep_distance': 1.0,
#   'max_dep_distance': 2,
#   'long_deps_count': 0,
#   'noun_count': 2,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.6666666666666666,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 2,
#   'avg_dependents': 0.6666666666666666,
#   'max_dependents': 2,
#   'left_deps': 0,
#   'right_deps': 2,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 3,
#   'Sentence': 'عناصر المشكلة :'},
#  {'avg_dep_distance': 1.9166666666666667,
#   'max_dep_distance': 11,
#   'long_deps_count': 1,
#   'noun_count': 7,
#   'verb_count': 0,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.6666666666666666,
#   'sbj_count': 0,
#   'obj_count': 2,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 9,
#   'avg_dependents': 0.9166666666666666,
#   'max_dependents': 3,
#   'left_deps': 0,
#   'right_deps': 11,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 12,
#   'Sentence': 'المعطيات : الحالة الراهنة عند الشروع في العمل على حل المشكلة .'},
#  {'avg_dep_distance': 1.9166666666666667,
#   'max_dep_distance': 9,
#   'long_deps_count': 1,
#   'noun_count': 6,
#   'verb_count': 1,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 1,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.16666666666666666,
#   'content_word_ratio': 0.6666666666666666,
#   'sbj_count': 1,
#   'obj_count': 2,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 7,
#   'avg_dependents': 0.9166666666666666,
#   'max_dependents': 2,
#   'left_deps': 0,
#   'right_deps': 11,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 12,
#   'Sentence': 'الأهداف : تمثل الحالة المنشودة المطلوب بلوغها لحل المشكلة .'},
#  {'avg_dep_distance': 1.9230769230769231,
#   'max_dep_distance': 10,
#   'long_deps_count': 2,
#   'noun_count': 5,
#   'verb_count': 1,
#   'adj_count': 2,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 1,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.2,
#   'content_word_ratio': 0.6153846153846154,
#   'sbj_count': 0,
#   'obj_count': 3,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 8,
#   'avg_dependents': 0.9230769230769231,
#   'max_dependents': 2,
#   'left_deps': 0,
#   'right_deps': 12,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 13,
#   'Sentence': 'العقبات : الصعوبات التي تعيق الوصول من الحالة الراهنة إلى الحالة المنشودة .'},
#  {'avg_dep_distance': 1.25,
#   'max_dep_distance': 3,
#   'long_deps_count': 0,
#   'noun_count': 3,
#   'verb_count': 0,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.75,
#   'sbj_count': 0,
#   'obj_count': 0,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 3,
#   'avg_dependents': 0.75,
#   'max_dependents': 2,
#   'left_deps': 0,
#   'right_deps': 3,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 4,
#   'Sentence': 'خطوات حل المشكلة :'},
#  {'avg_dep_distance': 1.9090909090909092,
#   'max_dep_distance': 5,
#   'long_deps_count': 2,
#   'noun_count': 5,
#   'verb_count': 0,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 1,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.0,
#   'content_word_ratio': 0.5454545454545454,
#   'sbj_count': 1,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 6,
#   'avg_dependents': 0.9090909090909091,
#   'max_dependents': 4,
#   'left_deps': 1,
#   'right_deps': 9,
#   'left_right_dep_ratio': 0.1111111111111111,
#   'total_words': 11,
#   'Sentence': 'تحديد المشكلة : وهو التعرف إلى هوية المشكلة الأساسية .'},
#  {'avg_dep_distance': 2.090909090909091,
#   'max_dep_distance': 9,
#   'long_deps_count': 2,
#   'noun_count': 4,
#   'verb_count': 2,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 1,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 1,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.5,
#   'content_word_ratio': 0.5454545454545454,
#   'sbj_count': 2,
#   'obj_count': 1,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 5,
#   'avg_dependents': 0.9090909090909091,
#   'max_dependents': 4,
#   'left_deps': 3,
#   'right_deps': 7,
#   'left_right_dep_ratio': 0.42857142857142855,
#   'total_words': 11,
#   'Sentence': 'وكان هذا الوقت هو أحسن الأوقات لزيارة السلطان ,'},
#  {'avg_dep_distance': 3.1363636363636362,
#   'max_dep_distance': 20,
#   'long_deps_count': 5,
#   'noun_count': 10,
#   'verb_count': 2,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 1,
#   'cconj_count': 3,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 1,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.2,
#   'content_word_ratio': 0.5909090909090909,
#   'sbj_count': 1,
#   'obj_count': 4,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 7,
#   'avg_dependents': 0.9545454545454546,
#   'max_dependents': 5,
#   'left_deps': 4,
#   'right_deps': 17,
#   'left_right_dep_ratio': 0.23529411764705882,
#   'total_words': 22,
#   'Sentence': 'وكان رئيس الوزراء واسمه المنصور , يختار هذا الوقت في كل يوم لمقابلة السلطان والتحدث معه .'},
#  {'avg_dep_distance': 2.0,
#   'max_dep_distance': 5,
#   'long_deps_count': 2,
#   'noun_count': 5,
#   'verb_count': 1,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 0,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.2,
#   'content_word_ratio': 0.6,
#   'sbj_count': 1,
#   'obj_count': 2,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 4,
#   'avg_dependents': 0.9,
#   'max_dependents': 5,
#   'left_deps': 2,
#   'right_deps': 7,
#   'left_right_dep_ratio': 0.2857142857142857,
#   'total_words': 10,
#   'Sentence': 'وفي ذات يوم أقبل رئيس الوزراء على السلطان ,'},
#  {'avg_dep_distance': 3.5135135135135136,
#   'max_dep_distance': 30,
#   'long_deps_count': 8,
#   'noun_count': 8,
#   'verb_count': 6,
#   'adj_count': 2,
#   'adv_count': 0,
#   'adp_count': 4,
#   'pron_count': 5,
#   'cconj_count': 7,
#   'num_count': 0,
#   'punct_count': 4,
#   'sconj_count': 0,
#   'part_count': 1,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.75,
#   'content_word_ratio': 0.43243243243243246,
#   'sbj_count': 2,
#   'obj_count': 13,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 9,
#   'avg_dependents': 0.972972972972973,
#   'max_dependents': 9,
#   'left_deps': 2,
#   'right_deps': 34,
#   'left_right_dep_ratio': 0.058823529411764705,
#   'total_words': 37,
#   'Sentence': 'فلما صار قريبا منه انحنى أمامه وحياه , فرد السلطان على التحية وأمره بالجلوس , فجلس ساكتا , وعلى وجهه علامات الهم والحزن ,'},
#  {'avg_dep_distance': 2.1538461538461537,
#   'max_dep_distance': 6,
#   'long_deps_count': 2,
#   'noun_count': 3,
#   'verb_count': 2,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 3,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 1,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.6666666666666666,
#   'content_word_ratio': 0.46153846153846156,
#   'sbj_count': 2,
#   'obj_count': 4,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 4,
#   'avg_dependents': 0.9230769230769231,
#   'max_dependents': 5,
#   'left_deps': 2,
#   'right_deps': 10,
#   'left_right_dep_ratio': 0.2,
#   'total_words': 13,
#   'Sentence': 'فسأله السلطان : مالي أراك حزينا أيها الوزير ?'},
#  {'avg_dep_distance': 2.0833333333333335,
#   'max_dep_distance': 11,
#   'long_deps_count': 2,
#   'noun_count': 2,
#   'verb_count': 3,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 1,
#   'cconj_count': 1,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 1,
#   'part_count': 1,
#   'det_count': 0,
#   'aux_count': 1,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 1.5,
#   'content_word_ratio': 0.5,
#   'sbj_count': 2,
#   'obj_count': 2,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 7,
#   'avg_dependents': 0.9166666666666666,
#   'max_dependents': 3,
#   'left_deps': 1,
#   'right_deps': 10,
#   'left_right_dep_ratio': 0.1,
#   'total_words': 12,
#   'Sentence': 'لا شك أن أمرا عظيما قد حدث فشغل بالك .'},
#  {'avg_dep_distance': 1.6666666666666667,
#   'max_dep_distance': 5,
#   'long_deps_count': 1,
#   'noun_count': 0,
#   'verb_count': 2,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 1,
#   'pron_count': 2,
#   'cconj_count': 0,
#   'num_count': 0,
#   'punct_count': 1,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0,
#   'content_word_ratio': 0.3333333333333333,
#   'sbj_count': 0,
#   'obj_count': 2,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 4,
#   'avg_dependents': 0.8333333333333334,
#   'max_dependents': 3,
#   'left_deps': 0,
#   'right_deps': 5,
#   'left_right_dep_ratio': 0.0,
#   'total_words': 6,
#   'Sentence': 'حدثني عما جرى .'},
#  {'avg_dep_distance': 3.5,
#   'max_dep_distance': 36,
#   'long_deps_count': 9,
#   'noun_count': 14,
#   'verb_count': 4,
#   'adj_count': 1,
#   'adv_count': 0,
#   'adp_count': 2,
#   'pron_count': 4,
#   'cconj_count': 4,
#   'num_count': 0,
#   'punct_count': 6,
#   'sconj_count': 0,
#   'part_count': 2,
#   'det_count': 0,
#   'aux_count': 1,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.2857142857142857,
#   'content_word_ratio': 0.5,
#   'sbj_count': 2,
#   'obj_count': 10,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 10,
#   'avg_dependents': 0.9736842105263158,
#   'max_dependents': 9,
#   'left_deps': 5,
#   'right_deps': 32,
#   'left_right_dep_ratio': 0.15625,
#   'total_words': 38,
#   'Sentence': 'فوضع رئيس الوزراء يديه على صدره وقال : يا مولاي السلطان , لقد رأيت الآن , في فناء القصر وأنا داخل , تاجرا يبيع أشياء غالية , وجواهر ثمينة ,'},
#  {'avg_dep_distance': 4.5777777777777775,
#   'max_dep_distance': 43,
#   'long_deps_count': 10,
#   'noun_count': 12,
#   'verb_count': 6,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 6,
#   'pron_count': 8,
#   'cconj_count': 6,
#   'num_count': 0,
#   'punct_count': 4,
#   'sconj_count': 1,
#   'part_count': 2,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.5,
#   'content_word_ratio': 0.4,
#   'sbj_count': 2,
#   'obj_count': 13,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 12,
#   'avg_dependents': 0.9777777777777777,
#   'max_dependents': 7,
#   'left_deps': 2,
#   'right_deps': 42,
#   'left_right_dep_ratio': 0.047619047619047616,
#   'total_words': 45,
#   'Sentence': 'وكنت أحب أن أشتري شيئا مما معه , ولكني لم أستطع لقلة ما عندي من المال , فحزنت في نفسي , وظهر على وجهي ما رأيت يا مولاي من علامات الهم والألم .'},
#  {'avg_dep_distance': 2.8529411764705883,
#   'max_dep_distance': 32,
#   'long_deps_count': 4,
#   'noun_count': 6,
#   'verb_count': 7,
#   'adj_count': 2,
#   'adv_count': 0,
#   'adp_count': 4,
#   'pron_count': 7,
#   'cconj_count': 3,
#   'num_count': 0,
#   'punct_count': 4,
#   'sconj_count': 1,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 1.1666666666666667,
#   'content_word_ratio': 0.4411764705882353,
#   'sbj_count': 3,
#   'obj_count': 10,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 16,
#   'avg_dependents': 0.9705882352941176,
#   'max_dependents': 7,
#   'left_deps': 1,
#   'right_deps': 32,
#   'left_right_dep_ratio': 0.03125,
#   'total_words': 34,
#   'Sentence': 'وكان السلطان , حين أقبل عليه وزيره الأول , جالسا يفكر في شعبه , وفي الأعمال التي يجب أن يعملها ليسعد أمته ويرقيها ,'},
#  {'avg_dep_distance': 2.7333333333333334,
#   'max_dep_distance': 28,
#   'long_deps_count': 4,
#   'noun_count': 12,
#   'verb_count': 2,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 6,
#   'pron_count': 5,
#   'cconj_count': 3,
#   'num_count': 0,
#   'punct_count': 2,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.16666666666666666,
#   'content_word_ratio': 0.4666666666666667,
#   'sbj_count': 0,
#   'obj_count': 8,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 12,
#   'avg_dependents': 0.9666666666666667,
#   'max_dependents': 4,
#   'left_deps': 1,
#   'right_deps': 28,
#   'left_right_dep_ratio': 0.03571428571428571,
#   'total_words': 30,
#   'Sentence': 'وكان يفكر أيضا في تقديم هدية إلى رئيس وزرائه , تقديرا لإخلاصه ومكافأة له على اجتهاده واهتمامه بأمور الشعب .'},
#  {'avg_dep_distance': 3.2580645161290325,
#   'max_dep_distance': 20,
#   'long_deps_count': 6,
#   'noun_count': 10,
#   'verb_count': 5,
#   'adj_count': 0,
#   'adv_count': 0,
#   'adp_count': 3,
#   'pron_count': 4,
#   'cconj_count': 4,
#   'num_count': 0,
#   'punct_count': 3,
#   'sconj_count': 0,
#   'part_count': 1,
#   'det_count': 1,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.5,
#   'content_word_ratio': 0.4838709677419355,
#   'sbj_count': 2,
#   'obj_count': 10,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 8,
#   'avg_dependents': 0.967741935483871,
#   'max_dependents': 7,
#   'left_deps': 3,
#   'right_deps': 27,
#   'left_right_dep_ratio': 0.1111111111111111,
#   'total_words': 31,
#   'Sentence': 'فلما حدثه الوزير عن سبب حزنه , انتهز هذه الفرصة وأمر بإحضار التاجر أمامه , فذهب الخادم وأحضره من فناء القصر .'},
#  {'avg_dep_distance': 3.85,
#   'max_dep_distance': 18,
#   'long_deps_count': 6,
#   'noun_count': 8,
#   'verb_count': 3,
#   'adj_count': 3,
#   'adv_count': 0,
#   'adp_count': 0,
#   'pron_count': 0,
#   'cconj_count': 2,
#   'num_count': 0,
#   'punct_count': 4,
#   'sconj_count': 0,
#   'part_count': 0,
#   'det_count': 0,
#   'aux_count': 0,
#   'intj_count': 0,
#   'pipe_count': 0,
#   'verb_to_noun_ratio': 0.375,
#   'content_word_ratio': 0.7,
#   'sbj_count': 2,
#   'obj_count': 3,
#   'advcl_count': 0,
#   'acl_count': 0,
#   'conj_count': 0,
#   'cc_count': 0,
#   'max_depth': 5,
#   'avg_dependents': 0.95,
#   'max_dependents': 6,
#   'left_deps': 1,
#   'right_deps': 18,
#   'left_right_dep_ratio': 0.05555555555555555,
#   'total_words': 20,
#   'Sentence': 'وكان التاجر رجلا قصير القامة , قبيح الوجه , يلبس ملابس قديمة , ويحمل معه صندوقا صغيرا ,'},
#  ...]

# %%
# extract all pos tags with sentence from all_parsed_blocks and save sentence as key, pos tags as value
pos_tags_dict = {}
for block in all_parsed_blocks:
    sentence = extract_sentence_from_block(block)
    sentence = sentence
    if sentence is not None:
        pos_tags = extract_pos_tags_from_block(block)
        pos_tags_dict[sentence] = pos_tags

# save file to pos_tags_dict.json
with open(f"{OUTPUT_DIR}/pos_tags_dict_{Split}.json", "w", encoding="utf-8") as f:
    import json
    json.dump(pos_tags_dict, f, ensure_ascii=False, indent=4)

# %%
# Features you want to extract
all_features = [
    "ud", "prc3", "prc2", "prc1", "prc0", "enc0", "gen", "num", "cas", "per", "asp", "vox", "mod", "stt", "rat", "token_type"
]

# Main loop over blocks
morph_features_dict = {}
for block in all_parsed_blocks:
    sentence = extract_sentence_from_block(block)
    if sentence is not None:
        morph_features = extract_morph_features_from_block(block, all_features)
        morph_features_dict[sentence] = morph_features

# Save to JSON
output_path = os.path.join(OUTPUT_DIR, f"morph_features_dict_{Split}.json")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(morph_features_dict, f, ensure_ascii=False, indent=4)

print(f"Saved morphological features to {output_path}")
# Out:
# Saved morphological features to ./splits_blind_testset/morph_features_dict_blind_testset.json

# %%
# TODO:: very important when joining -> 
# replace the arabic punctuation marks with english ? 
# add space after the arabic punctuation marks if not already there

def build_dep_graph(block):
    """
    Build a dependency graph from a CoNLL block.
    Returns: dict with nodes and edges
    """
    def get_token_type(feat_str):
        if feat_str == "_" or feat_str.strip() == "":
            return {}
        all_feats = dict(item.split("=") for item in feat_str.split("|") if "=" in item)
        return all_feats.get('token_type', 'baseword')  # Default to 'baseword' if not found
    
    sentence = extract_sentence_from_block(block)
    
    if sentence is None:
        return {'nodes': [], 'edges': []}
    
    lines = block[1:]  # Skip the first line which is the sentence line

    tokens_data = []
    for line in lines:
        parts = line.split('\t')
        token_id = int(parts[0])
        form = parts[1]
        if "NOAN" in form:
            # replace "NOAN" with the next part, also replace only "NOAN" not the whole, since for example we have "الNOAN" زنا -> should be "الزنا"
            form = form.replace("NOAN", parts[2])
        head = parts[6]
        dep = parts[7]
        pos_tag = get_upos(parts[5])
        token_type = get_token_type(parts[5])  # Extract token type from the features
        
        tokens_data.append({
            'id': token_id,
            'form': form,
            'head': head,
            'dep': dep,
            'token_type': token_type,
            'pos_tag': pos_tag,  # Add POS tag to the token data
        })

    merged_results = []
    current_word_tokens = []
    current_word_form = ""
    current_word_tokens_contain_baseword = False  # Track if the current word contains a baseword
    map_english_punctuation = {
        ";": ["؛"],  # Arabic semicolon
        ",": ["،", "٫"],  # Arabic comma
        "?": ["؟"],  # Arabic question mark
        "%": ["٪"],  # Arabic percentage sign
        "*": ["۝"],  # Arabic symbol for verse end
    }
    # map_english_punctuation_values = [punct for puncts in map_english_punctuation.values() for punct in puncts]
    # count all the punctuations found in sentence
    punctuations_occurences = []
    for i, letter in enumerate(sentence):
        if letter in map_english_punctuation.keys():
            punctuations_occurences.append(i)

    # Add space after the arabic punctuation marks if its directly attached to the next word
    offset = 0
    for index in punctuations_occurences:
        adjusted_index = index + offset
        if adjusted_index < len(sentence) - 1 and sentence[adjusted_index + 1] != ' ':
            sentence = sentence[:adjusted_index + 1] + ' ' + sentence[adjusted_index + 1:]
            offset += 1  # Adjust offset due to inserted space


    # print(f"Processed sentence: {sentence}")

    # count all the punctuations found in sentence again after adding spaces
    punctuations_occurences = []
    for i, letter in enumerate(sentence):
        if letter in map_english_punctuation.keys():
            punctuations_occurences.append(i)

    print(f"Total punctuations found in sentence: {[sentence[pun] for pun in punctuations_occurences]}")

    current_punctuations_index = 0

    for token in tokens_data:
        form = token['form']
        token_type = token['token_type']
        
        if token_type.startswith('prc'):
            # means a new word is getting started, we need to save the previous word if exists
            if current_word_tokens and current_word_tokens_contain_baseword:
                # Only save if the current word is a baseword
                merged_results.append({
                    'word': current_word_form,
                    'token_ids': [t['id'] for t in current_word_tokens],
                    'heads': [t['head'] for t in current_word_tokens],
                    'deps': [t['dep'] for t in current_word_tokens],
                    'pos_tags': [t['pos_tag'] for t in current_word_tokens],
                    'merged_form': "".join([t['form'].lstrip('+').rstrip('+') for t in current_word_tokens]),
                })
                # Reset current word group
                current_word_tokens = []
                current_word_form = ""

            # Start new word group
            current_word_tokens_contain_baseword = False
            current_word_tokens.append(token)
            current_word_form += form.lstrip('+').rstrip('+')
            
            continue

        if token_type == 'baseword':
            # special case for ";" baseword, sometimes its combined with previous word
            
            if form in map_english_punctuation.keys():
                # we need first to check if its really combined with previous word, need to add all of its properties too
                
                # get the occurence of the punctuation in the sentence
                if current_punctuations_index < len(punctuations_occurences):
                    punctuation_index = punctuations_occurences[current_punctuations_index]
                else:
                    raise Exception(f"Current punctuations index {current_punctuations_index} is out of bounds for sentence: {sentence}")

                # Check if the punctuation is concatenated directly to the previous/next word, or there is a space before it
                # case where the punctuation is directly attached to the next word
                if (punctuation_index < len(sentence) - 1 and sentence[punctuation_index + 1] != ' '):
                    raise Exception(f"Unexpected punctuation '{form}' at index {punctuation_index} in sentence: {sentence}")
                
                if (punctuation_index > 0 and sentence[punctuation_index - 1] != ' '):
                    # print(f"Found '{current_word_form + map_english_punctuation[form]}' in sentence, merging...")
                    # If the current word is part of the sentence, we merge it
                    current_word_tokens.append(token)
                    current_word_form += form.lstrip('+').rstrip('+')

                    # Save previous word if exists
                    if current_word_tokens:
                        merged_results.append({
                            'word': current_word_form,
                            'token_ids': [t['id'] for t in current_word_tokens],
                            'heads': [t['head'] for t in current_word_tokens],
                            'deps': [t['dep'] for t in current_word_tokens],
                            'pos_tags': [t['pos_tag'] for t in current_word_tokens],
                            'merged_form': "".join([t['form'].lstrip('+').rstrip('+') for t in current_word_tokens]),
                        })
                    # Start new word group
                    current_word_tokens = []
                    current_word_form = ""
                    current_word_tokens_contain_baseword = False
                    # increment current_punctuations_index
                    current_punctuations_index += 1
                    continue
                else:
                    # increment current_punctuations_index
                    current_punctuations_index += 1

            # Save previous word if exists
            if current_word_tokens and current_word_tokens_contain_baseword:
                # Only save if the current word is a baseword
                merged_results.append({
                    'word': current_word_form,
                    'token_ids': [t['id'] for t in current_word_tokens],
                    'heads': [t['head'] for t in current_word_tokens],
                    'deps': [t['dep'] for t in current_word_tokens],
                    'pos_tags': [t['pos_tag'] for t in current_word_tokens],
                    'merged_form': "".join([t['form'].lstrip('+').rstrip('+') for t in current_word_tokens]),
                })
                # Reset current word group
                current_word_tokens = []
                current_word_form = ""

            # Start new word group
            current_word_tokens_contain_baseword = True
            current_word_tokens.append(token)
            current_word_form += form.lstrip('+').rstrip('+')
        else:
            # Add clitic or enc0 tokens to current word group
            current_word_tokens.append(token)
            current_word_form += form.lstrip('+').rstrip('+')

    # Append last word group after loop
    if current_word_tokens:
        merged_results.append({
            'word': current_word_form,
            'token_ids': [t['id'] for t in current_word_tokens],
            'heads': [t['head'] for t in current_word_tokens],
            'deps': [t['dep'] for t in current_word_tokens],
            'pos_tags': [t['pos_tag'] for t in current_word_tokens],
            'merged_form': "".join([t['form'].lstrip('+') for t in current_word_tokens]),
        })

    # Map from token_id to merged word index (1-based)
    tokenid_to_merged_idx = {}
    for merged_idx, merged_token in enumerate(merged_results, 1):
        for tid in merged_token['token_ids']:
            tokenid_to_merged_idx[tid] = merged_idx

    # Build heads mapping to merged node indices
    for entry in merged_results:
        heads_graph = []
        for head in entry['heads']:
            head_id = int(head)
            if head_id == 0:
                heads_graph.append(0)  # Root
            else:
                merged_head_idx = tokenid_to_merged_idx.get(head_id, -1)
                heads_graph.append(merged_head_idx)
        entry['Heads_graph'] = heads_graph

    # Construct nodes and edges for graph
    nodes = []
    edges = []

    for idx, entry in enumerate(merged_results, 1):
        nodes.append({
            'id': idx,
            'word': entry['word'],
            'token_ids': entry['token_ids'],
            'pos_tags': entry['pos_tags'],
        })

        for head_idx, dep in zip(entry['Heads_graph'], entry['deps']):
            if head_idx != 0: # and head_idx != idx: why should we not include self-loops?
                edges.append({
                    'source': head_idx,
                    'target': idx,
                    'dep': dep,
                })
            elif head_idx == 0:
                # Optionally add edges from root node (id=0)
                edges.append({
                    'source': 0,
                    'target': idx,
                    'dep': dep,
                })

    # Check nodes are of same length as space separated words in sentence
    if len(nodes) != len(sentence.split()):
        raise Exception(f"Warning: Number of nodes ({len(nodes)}) does not match number of words in sentence ({len(sentence.split())}), sentence: {sentence}")

    return {
        'nodes': nodes,
        'edges': edges,
    }

# Build dependency graphs for all blocks
dep_graphs_dict = {}
for i, block in enumerate(all_parsed_blocks):
    print(f"Processing block {i}...")
    dep_graph = build_dep_graph(block)
    print(f"Block {i} processed with {len(dep_graph['nodes'])} nodes and {len(dep_graph['edges'])} edges.")
    sentence = extract_sentence_from_block(block)
    dep_graphs_dict[sentence] = dep_graph

# Save to JSON
output_path = os.path.join(OUTPUT_DIR, f"dep_graph_{Split}.json")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(dep_graphs_dict, f, ensure_ascii=False, indent=4)

print(f"Saved dep_graphs_dict to {output_path}")

# build_dep_graph(all_parsed_blocks[30109])
# Out:
# Processing block 0...
# Total punctuations found in sentence: []
# Block 0 processed with 5 nodes and 6 edges.
# Processing block 1...
# Total punctuations found in sentence: []
# Block 1 processed with 2 nodes and 2 edges.
# Processing block 2...
# Total punctuations found in sentence: []
# Block 2 processed with 5 nodes and 5 edges.
# Processing block 3...
# Total punctuations found in sentence: []
# Block 3 processed with 5 nodes and 5 edges.
# Processing block 4...
# Total punctuations found in sentence: []
# Block 4 processed with 2 nodes and 2 edges.
# Processing block 5...
# Total punctuations found in sentence: []
# Block 5 processed with 3 nodes and 3 edges.
# Processing block 6...
# Total punctuations found in sentence: []
# Block 6 processed with 4 nodes and 4 edges.
# Processing block 7...
# Total punctuations found in sentence: []
# Block 7 processed with 1 nodes and 1 edges.
# Processing block 8...
# Total punctuations found in sentence: []
# Block 8 processed with 1 nodes and 1 edges.
# Processing block 9...
# Total punctuations found in sentence: []
# Block 9 processed with 1 nodes and 1 edges.
# Processing block 10...
# Total punctuations found in sentence: []
# Block 10 processed with 3 nodes and 3 edges.
# Processing block 11...
# Total punctuations found in sentence: []
# Block 11 processed with 116 nodes and 116 edges.
# Processing block 12...
# Total punctuations found in sentence: ['?']
# Block 12 processed with 8 nodes and 9 edges.
# Processing block 13...
# Total punctuations found in sentence: ['?']
# Block 13 processed with 2 nodes and 2 edges.
# Processing block 14...
# Total punctuations found in sentence: []
# Block 14 processed with 3 nodes and 3 edges.
# Processing block 15...
# Total punctuations found in sentence: []
# Block 15 processed with 19 nodes and 22 edges.
# Processing block 16...
# Total punctuations found in sentence: []
# Block 16 processed with 10 nodes and 17 edges.
# Processing block 17...
# Total punctuations found in sentence: []
# Block 17 processed with 20 nodes and 23 edges.
# Processing block 18...
# Total punctuations found in sentence: []
# Block 18 processed with 11 nodes and 14 edges.
# Processing block 19...
# Total punctuations found in sentence: []
# Block 19 processed with 10 nodes and 14 edges.
# Processing block 20...
# Total punctuations found in sentence: []
# Block 20 processed with 11 nodes and 15 edges.
# Processing block 21...
# Total punctuations found in sentence: []
# Block 21 processed with 9 nodes and 15 edges.
# Processing block 22...
# Total punctuations found in sentence: []
# Block 22 processed with 4 nodes and 4 edges.
# Processing block 23...
# Total punctuations found in sentence: []
# Block 23 processed with 7 nodes and 8 edges.
# Processing block 24...
# Total punctuations found in sentence: ['?']
# Block 24 processed with 7 nodes and 8 edges.
# Processing block 25...
# Total punctuations found in sentence: ['?']
# Block 25 processed with 7 nodes and 7 edges.
# Processing block 26...
# Total punctuations found in sentence: []
# Block 26 processed with 3 nodes and 4 edges.
# Processing block 27...
# Total punctuations found in sentence: ['?']
# Block 27 processed with 12 nodes and 13 edges.
# Processing block 28...
# Total punctuations found in sentence: [',']
# Block 28 processed with 27 nodes and 34 edges.
# Processing block 29...
# Total punctuations found in sentence: []
# Block 29 processed with 12 nodes and 16 edges.
# Processing block 30...
# Total punctuations found in sentence: [',']
# Block 30 processed with 24 nodes and 33 edges.
# Processing block 31...
# Total punctuations found in sentence: [',']
# Block 31 processed with 13 nodes and 17 edges.
# Processing block 32...
# Total punctuations found in sentence: [',', ',']
# Block 32 processed with 15 nodes and 27 edges.
# Processing block 33...
# Total punctuations found in sentence: [',', ',']
# Block 33 processed with 29 nodes and 39 edges.
# Processing block 34...
# Total punctuations found in sentence: []
# Block 34 processed with 20 nodes and 28 edges.
# Processing block 35...
# Total punctuations found in sentence: []
# Block 35 processed with 2 nodes and 3 edges.
# Processing block 36...
# Total punctuations found in sentence: []
# Block 36 processed with 1 nodes and 1 edges.
# Processing block 37...
# Total punctuations found in sentence: []
# Block 37 processed with 6 nodes and 7 edges.
# Processing block 38...
# Total punctuations found in sentence: []
# Block 38 processed with 5 nodes and 5 edges.
# Processing block 39...
# Total punctuations found in sentence: []
# Block 39 processed with 7 nodes and 7 edges.
# Processing block 40...
# Total punctuations found in sentence: ['?']
# Block 40 processed with 7 nodes and 7 edges.
# Processing block 41...
# Total punctuations found in sentence: []
# Block 41 processed with 3 nodes and 3 edges.
# Processing block 42...
# Total punctuations found in sentence: []
# Block 42 processed with 3 nodes and 3 edges.
# Processing block 43...
# Total punctuations found in sentence: [',', ',', ',']
# Block 43 processed with 16 nodes and 21 edges.
# Processing block 44...
# Total punctuations found in sentence: [',']
# Block 44 processed with 8 nodes and 11 edges.
# Processing block 45...
# Total punctuations found in sentence: []
# Block 45 processed with 6 nodes and 6 edges.
# Processing block 46...
# Total punctuations found in sentence: [',', ',']
# Block 46 processed with 18 nodes and 26 edges.
# Processing block 47...
# Total punctuations found in sentence: [',', ',']
# Block 47 processed with 29 nodes and 35 edges.
# Processing block 48...
# Total punctuations found in sentence: [',']
# Block 48 processed with 8 nodes and 9 edges.
# Processing block 49...
# Total punctuations found in sentence: [',']
# Block 49 processed with 9 nodes and 13 edges.
# Processing block 50...
# Total punctuations found in sentence: [',', ',']
# Block 50 processed with 17 nodes and 22 edges.
# Processing block 51...
# Total punctuations found in sentence: []
# Block 51 processed with 8 nodes and 8 edges.
# Processing block 52...
# Total punctuations found in sentence: []
# Block 52 processed with 9 nodes and 11 edges.
# Processing block 53...
# Total punctuations found in sentence: [',', ',', ',']
# Block 53 processed with 17 nodes and 22 edges.
# Processing block 54...
# Total punctuations found in sentence: [',', ',', ',']
# Block 54 processed with 34 nodes and 42 edges.
# Processing block 55...
# Total punctuations found in sentence: []
# Block 55 processed with 2 nodes and 2 edges.
# Processing block 56...
# Total punctuations found in sentence: []
# Block 56 processed with 2 nodes and 2 edges.
# Processing block 57...
# Total punctuations found in sentence: []
# Block 57 processed with 7 nodes and 7 edges.
# Processing block 58...
# Total punctuations found in sentence: [',']
# Block 58 processed with 10 nodes and 13 edges.
# Processing block 59...
# Total punctuations found in sentence: [',']
# Block 59 processed with 18 nodes and 23 edges.
# Processing block 60...
# Total punctuations found in sentence: []
# Block 60 processed with 4 nodes and 4 edges.
# Processing block 61...
# Total punctuations found in sentence: []
# Block 61 processed with 4 nodes and 6 edges.
# Processing block 62...
# Total punctuations found in sentence: ['?']
# Block 62 processed with 5 nodes and 7 edges.
# Processing block 63...
# Total punctuations found in sentence: []
# Block 63 processed with 6 nodes and 9 edges.
# Processing block 64...
# Total punctuations found in sentence: []
# Block 64 processed with 7 nodes and 10 edges.
# Processing block 65...
# Total punctuations found in sentence: []
# Block 65 processed with 4 nodes and 5 edges.
# Processing block 66...
# Total punctuations found in sentence: []
# Block 66 processed with 5 nodes and 7 edges.
# Processing block 67...
# Total punctuations found in sentence: []
# Block 67 processed with 3 nodes and 3 edges.
# Processing block 68...
# Total punctuations found in sentence: []
# Block 68 processed with 4 nodes and 4 edges.
# Processing block 69...
# Total punctuations found in sentence: ['?']
# Block 69 processed with 3 nodes and 3 edges.
# Processing block 70...
# Total punctuations found in sentence: []
# Block 70 processed with 6 nodes and 6 edges.
# Processing block 71...
# Total punctuations found in sentence: []
# Block 71 processed with 1 nodes and 1 edges.
# Processing block 72...
# Total punctuations found in sentence: []
# Block 72 processed with 3 nodes and 3 edges.
# Processing block 73...
# Total punctuations found in sentence: []
# Block 73 processed with 5 nodes and 7 edges.
# Processing block 74...
# Total punctuations found in sentence: []
# Block 74 processed with 5 nodes and 6 edges.
# Processing block 75...
# Total punctuations found in sentence: []
# Block 75 processed with 4 nodes and 7 edges.
# Processing block 76...
# Total punctuations found in sentence: ['?']
# Block 76 processed with 6 nodes and 8 edges.
# Processing block 77...
# Total punctuations found in sentence: []
# Block 77 processed with 7 nodes and 8 edges.
# Processing block 78...
# Total punctuations found in sentence: []
# Block 78 processed with 7 nodes and 11 edges.
# Processing block 79...
# Total punctuations found in sentence: []
# Block 79 processed with 4 nodes and 5 edges.
# Processing block 80...
# Total punctuations found in sentence: []
# Block 80 processed with 10 nodes and 12 edges.
# Processing block 81...
# Total punctuations found in sentence: []
# Block 81 processed with 5 nodes and 5 edges.
# Processing block 82...
# Total punctuations found in sentence: []
# Block 82 processed with 3 nodes and 3 edges.
# Processing block 83...
# Total punctuations found in sentence: []
# Block 83 processed with 6 nodes and 6 edges.
# Processing block 84...
# Total punctuations found in sentence: []
# Block 84 processed with 8 nodes and 11 edges.
# Processing block 85...
# Total punctuations found in sentence: []
# Block 85 processed with 6 nodes and 9 edges.
# Processing block 86...
# Total punctuations found in sentence: ['?']
# Block 86 processed with 3 nodes and 3 edges.
# Processing block 87...
# Total punctuations found in sentence: ['?']
# Block 87 processed with 3 nodes and 4 edges.
# Processing block 88...
# Total punctuations found in sentence: []
# Block 88 processed with 4 nodes and 4 edges.
# Processing block 89...
# Total punctuations found in sentence: []
# Block 89 processed with 5 nodes and 5 edges.
# Processing block 90...
# Total punctuations found in sentence: ['?']
# Block 90 processed with 2 nodes and 2 edges.
# Processing block 91...
# Total punctuations found in sentence: []
# Block 91 processed with 4 nodes and 5 edges.
# Processing block 92...
# Total punctuations found in sentence: []
# Block 92 processed with 3 nodes and 6 edges.
# Processing block 93...
# Total punctuations found in sentence: []
# Block 93 processed with 3 nodes and 3 edges.
# Processing block 94...
# Total punctuations found in sentence: []
# Block 94 processed with 5 nodes and 7 edges.
# Processing block 95...
# Total punctuations found in sentence: []
# Block 95 processed with 3 nodes and 5 edges.
# Processing block 96...
# Total punctuations found in sentence: []
# Block 96 processed with 9 nodes and 10 edges.
# Processing block 97...
# Total punctuations found in sentence: []
# Block 97 processed with 2 nodes and 2 edges.
# Processing block 98...
# Total punctuations found in sentence: []
# Block 98 processed with 5 nodes and 5 edges.
# Processing block 99...
# Total punctuations found in sentence: []
# Block 99 processed with 12 nodes and 13 edges.
# Processing block 100...
# Total punctuations found in sentence: [',']
# Block 100 processed with 29 nodes and 30 edges.
# Processing block 101...
# Total punctuations found in sentence: [',']
# Block 101 processed with 24 nodes and 31 edges.
# Processing block 102...
# Total punctuations found in sentence: []
# Block 102 processed with 20 nodes and 22 edges.
# Processing block 103...
# Total punctuations found in sentence: [',', ',']
# Block 103 processed with 11 nodes and 14 edges.
# Processing block 104...
# Total punctuations found in sentence: []
# Block 104 processed with 7 nodes and 9 edges.
# Processing block 105...
# Total punctuations found in sentence: []
# Block 105 processed with 18 nodes and 18 edges.
# Processing block 106...
# Total punctuations found in sentence: [',', ',']
# Block 106 processed with 20 nodes and 23 edges.
# Processing block 107...
# Total punctuations found in sentence: [',', ',']
# Block 107 processed with 28 nodes and 30 edges.
# Processing block 108...
# Total punctuations found in sentence: [',']
# Block 108 processed with 14 nodes and 16 edges.
# Processing block 109...
# Total punctuations found in sentence: [',', ',']
# Block 109 processed with 43 nodes and 46 edges.
# Processing block 110...
# Total punctuations found in sentence: [',']
# Block 110 processed with 36 nodes and 39 edges.
# Processing block 111...
# Total punctuations found in sentence: []
# Block 111 processed with 17 nodes and 18 edges.
# Processing block 112...
# Total punctuations found in sentence: [',']
# Block 112 processed with 23 nodes and 25 edges.
# Processing block 113...
# Total punctuations found in sentence: [',']
# Block 113 processed with 26 nodes and 29 edges.
# Processing block 114...
# Total punctuations found in sentence: []
# Block 114 processed with 1 nodes and 1 edges.
# Processing block 115...
# Total punctuations found in sentence: []
# Block 115 processed with 2 nodes and 2 edges.
# Processing block 116...
# Total punctuations found in sentence: []
# Block 116 processed with 4 nodes and 4 edges.
# Processing block 117...
# Total punctuations found in sentence: []
# Block 117 processed with 4 nodes and 4 edges.
# Processing block 118...
# Total punctuations found in sentence: [',']
# Block 118 processed with 5 nodes and 6 edges.
# Processing block 119...
# Total punctuations found in sentence: [',']
# Block 119 processed with 22 nodes and 29 edges.
# Processing block 120...
# Total punctuations found in sentence: ['?']
# Block 120 processed with 8 nodes and 8 edges.
# Processing block 121...
# Total punctuations found in sentence: []
# Block 121 processed with 3 nodes and 4 edges.
# Processing block 122...
# Total punctuations found in sentence: []
# Block 122 processed with 6 nodes and 7 edges.
# Processing block 123...
# Total punctuations found in sentence: []
# Block 123 processed with 8 nodes and 10 edges.
# Processing block 124...
# Total punctuations found in sentence: []
# Block 124 processed with 4 nodes and 5 edges.
# Processing block 125...
# Total punctuations found in sentence: ['?']
# Block 125 processed with 3 nodes and 3 edges.
# Processing block 126...
# Total punctuations found in sentence: []
# Block 126 processed with 4 nodes and 4 edges.
# Processing block 127...
# Total punctuations found in sentence: []
# Block 127 processed with 21 nodes and 23 edges.
# Processing block 128...
# Total punctuations found in sentence: []
# Block 128 processed with 9 nodes and 10 edges.
# Processing block 129...
# Total punctuations found in sentence: []
# Block 129 processed with 12 nodes and 19 edges.
# Processing block 130...
# Total punctuations found in sentence: []
# Block 130 processed with 11 nodes and 11 edges.
# Processing block 131...
# Total punctuations found in sentence: []
# Block 131 processed with 3 nodes and 3 edges.
# Processing block 132...
# Total punctuations found in sentence: []
# Block 132 processed with 8 nodes and 8 edges.
# Processing block 133...
# Total punctuations found in sentence: ['?']
# Block 133 processed with 5 nodes and 6 edges.
# Processing block 134...
# Total punctuations found in sentence: [',']
# Block 134 processed with 16 nodes and 19 edges.
# Processing block 135...
# Total punctuations found in sentence: []
# Block 135 processed with 15 nodes and 18 edges.
# Processing block 136...
# Total punctuations found in sentence: []
# Block 136 processed with 6 nodes and 8 edges.
# Processing block 137...
# Total punctuations found in sentence: []
# Block 137 processed with 7 nodes and 8 edges.
# Processing block 138...
# Total punctuations found in sentence: []
# Block 138 processed with 6 nodes and 8 edges.
# Processing block 139...
# Total punctuations found in sentence: []
# Block 139 processed with 6 nodes and 6 edges.
# Processing block 140...
# Total punctuations found in sentence: ['?']
# Block 140 processed with 8 nodes and 11 edges.
# Processing block 141...
# Total punctuations found in sentence: []
# Block 141 processed with 10 nodes and 10 edges.
# Processing block 142...
# Total punctuations found in sentence: []
# Block 142 processed with 10 nodes and 12 edges.
# Processing block 143...
# Total punctuations found in sentence: []
# Block 143 processed with 20 nodes and 27 edges.
# Processing block 144...
# Total punctuations found in sentence: []
# Block 144 processed with 8 nodes and 8 edges.
# Processing block 145...
# Total punctuations found in sentence: []
# Block 145 processed with 6 nodes and 8 edges.
# Processing block 146...
# Total punctuations found in sentence: []
# Block 146 processed with 9 nodes and 10 edges.
# Processing block 147...
# Total punctuations found in sentence: []
# Block 147 processed with 14 nodes and 18 edges.
# Processing block 148...
# Total punctuations found in sentence: []
# Block 148 processed with 15 nodes and 18 edges.
# Processing block 149...
# Total punctuations found in sentence: []
# Block 149 processed with 12 nodes and 15 edges.
# Processing block 150...
# Total punctuations found in sentence: []
# Block 150 processed with 3 nodes and 3 edges.
# Processing block 151...
# Total punctuations found in sentence: []
# Block 151 processed with 10 nodes and 11 edges.
# Processing block 152...
# Total punctuations found in sentence: [',']
# Block 152 processed with 12 nodes and 17 edges.
# Processing block 153...
# Total punctuations found in sentence: []
# Block 153 processed with 1 nodes and 1 edges.
# Processing block 154...
# Total punctuations found in sentence: [',']
# Block 154 processed with 11 nodes and 11 edges.
# Processing block 155...
# Total punctuations found in sentence: []
# Block 155 processed with 5 nodes and 7 edges.
# Processing block 156...
# Total punctuations found in sentence: []
# Block 156 processed with 4 nodes and 5 edges.
# Processing block 157...
# Total punctuations found in sentence: []
# Block 157 processed with 4 nodes and 6 edges.
# Processing block 158...
# Total punctuations found in sentence: []
# Block 158 processed with 5 nodes and 6 edges.
# Processing block 159...
# Total punctuations found in sentence: [',']
# Block 159 processed with 15 nodes and 15 edges.
# Processing block 160...
# Total punctuations found in sentence: []
# Block 160 processed with 8 nodes and 9 edges.
# Processing block 161...
# Total punctuations found in sentence: [',']
# Block 161 processed with 12 nodes and 13 edges.
# Processing block 162...
# Total punctuations found in sentence: []
# Block 162 processed with 4 nodes and 4 edges.
# Processing block 163...
# Total punctuations found in sentence: []
# Block 163 processed with 8 nodes and 8 edges.
# Processing block 164...
# Total punctuations found in sentence: []
# Block 164 processed with 8 nodes and 8 edges.
# Processing block 165...
# Total punctuations found in sentence: []
# Block 165 processed with 2 nodes and 2 edges.
# Processing block 166...
# Total punctuations found in sentence: [',']
# Block 166 processed with 23 nodes and 28 edges.
# Processing block 167...
# Total punctuations found in sentence: [',']
# Block 167 processed with 13 nodes and 17 edges.
# Processing block 168...
# Total punctuations found in sentence: []
# Block 168 processed with 7 nodes and 7 edges.
# Processing block 169...
# Total punctuations found in sentence: []
# Block 169 processed with 5 nodes and 5 edges.
# Processing block 170...
# Total punctuations found in sentence: []
# Block 170 processed with 2 nodes and 2 edges.
# Processing block 171...
# Total punctuations found in sentence: []
# Block 171 processed with 2 nodes and 2 edges.
# Processing block 172...
# Total punctuations found in sentence: []
# Block 172 processed with 2 nodes and 2 edges.
# Processing block 173...
# Total punctuations found in sentence: [',']
# Block 173 processed with 13 nodes and 13 edges.
# Processing block 174...
# Total punctuations found in sentence: []
# Block 174 processed with 2 nodes and 2 edges.
# Processing block 175...
# Total punctuations found in sentence: []
# Block 175 processed with 2 nodes and 2 edges.
# Processing block 176...
# Total punctuations found in sentence: []
# Block 176 processed with 4 nodes and 4 edges.
# Processing block 177...
# Total punctuations found in sentence: [',']
# Block 177 processed with 15 nodes and 16 edges.
# Processing block 178...
# Total punctuations found in sentence: [',', ',']
# Block 178 processed with 24 nodes and 31 edges.
# Processing block 179...
# Total punctuations found in sentence: [',', ',']
# Block 179 processed with 29 nodes and 34 edges.
# Processing block 180...
# Total punctuations found in sentence: []
# Block 180 processed with 2 nodes and 4 edges.
# Processing block 181...
# Total punctuations found in sentence: []
# Block 181 processed with 5 nodes and 6 edges.
# Processing block 182...
# Total punctuations found in sentence: []
# Block 182 processed with 4 nodes and 4 edges.
# Processing block 183...
# Total punctuations found in sentence: []
# Block 183 processed with 4 nodes and 4 edges.
# Processing block 184...
# Total punctuations found in sentence: [',']
# Block 184 processed with 8 nodes and 9 edges.
# Processing block 185...
# Total punctuations found in sentence: [',']
# Block 185 processed with 19 nodes and 29 edges.
# Processing block 186...
# Total punctuations found in sentence: ['?']
# Block 186 processed with 6 nodes and 8 edges.
# Processing block 187...
# Total punctuations found in sentence: []
# Block 187 processed with 2 nodes and 2 edges.
# Processing block 188...
# Total punctuations found in sentence: []
# Block 188 processed with 4 nodes and 5 edges.
# Processing block 189...
# Total punctuations found in sentence: []
# Block 189 processed with 8 nodes and 10 edges.
# Processing block 190...
# Total punctuations found in sentence: []
# Block 190 processed with 6 nodes and 8 edges.
# Processing block 191...
# Total punctuations found in sentence: []
# Block 191 processed with 1 nodes and 1 edges.
# Processing block 192...
# Total punctuations found in sentence: []
# Block 192 processed with 4 nodes and 5 edges.
# Processing block 193...
# Total punctuations found in sentence: []
# Block 193 processed with 10 nodes and 12 edges.
# Processing block 194...
# Total punctuations found in sentence: []
# Block 194 processed with 17 nodes and 23 edges.
# Processing block 195...
# Total punctuations found in sentence: []
# Block 195 processed with 8 nodes and 10 edges.
# Processing block 196...
# Total punctuations found in sentence: []
# Block 196 processed with 8 nodes and 10 edges.
# Processing block 197...
# Total punctuations found in sentence: []
# Block 197 processed with 3 nodes and 4 edges.
# Processing block 198...
# Total punctuations found in sentence: ['?']
# Block 198 processed with 6 nodes and 7 edges.
# Processing block 199...
# Total punctuations found in sentence: []
# Block 199 processed with 7 nodes and 8 edges.
# Processing block 200...
# Total punctuations found in sentence: []
# Block 200 processed with 3 nodes and 3 edges.
# Processing block 201...
# Total punctuations found in sentence: []
# Block 201 processed with 5 nodes and 6 edges.
# Processing block 202...
# Total punctuations found in sentence: []
# Block 202 processed with 9 nodes and 10 edges.
# Processing block 203...
# Total punctuations found in sentence: []
# Block 203 processed with 6 nodes and 10 edges.
# Processing block 204...
# Total punctuations found in sentence: []
# Block 204 processed with 5 nodes and 5 edges.
# Processing block 205...
# Total punctuations found in sentence: ['?']
# Block 205 processed with 13 nodes and 15 edges.
# Processing block 206...
# Total punctuations found in sentence: []
# Block 206 processed with 14 nodes and 20 edges.
# Processing block 207...
# Total punctuations found in sentence: []
# Block 207 processed with 7 nodes and 9 edges.
# Processing block 208...
# Total punctuations found in sentence: []
# Block 208 processed with 4 nodes and 7 edges.
# Processing block 209...
# Total punctuations found in sentence: [',']
# Block 209 processed with 9 nodes and 11 edges.
# Processing block 210...
# Total punctuations found in sentence: [',']
# Block 210 processed with 15 nodes and 19 edges.
# Processing block 211...
# Total punctuations found in sentence: []
# Block 211 processed with 2 nodes and 2 edges.
# Processing block 212...
# Total punctuations found in sentence: []
# Block 212 processed with 4 nodes and 4 edges.
# Processing block 213...
# Total punctuations found in sentence: []
# Block 213 processed with 4 nodes and 4 edges.
# Processing block 214...
# Total punctuations found in sentence: []
# Block 214 processed with 7 nodes and 10 edges.
# Processing block 215...
# Total punctuations found in sentence: []
# Block 215 processed with 4 nodes and 6 edges.
# Processing block 216...
# Total punctuations found in sentence: ['?']
# Block 216 processed with 3 nodes and 4 edges.
# Processing block 217...
# Total punctuations found in sentence: []
# Block 217 processed with 8 nodes and 9 edges.
# Processing block 218...
# Total punctuations found in sentence: []
# Block 218 processed with 2 nodes and 2 edges.
# Processing block 219...
# Total punctuations found in sentence: []
# Block 219 processed with 4 nodes and 6 edges.
# Processing block 220...
# Total punctuations found in sentence: []
# Block 220 processed with 4 nodes and 4 edges.
# Processing block 221...
# Total punctuations found in sentence: []
# Block 221 processed with 5 nodes and 5 edges.
# Processing block 222...
# Total punctuations found in sentence: ['?']
# Block 222 processed with 5 nodes and 6 edges.
# Processing block 223...
# Total punctuations found in sentence: []
# Block 223 processed with 3 nodes and 3 edges.
# Processing block 224...
# Total punctuations found in sentence: []
# Block 224 processed with 4 nodes and 5 edges.
# Processing block 225...
# Total punctuations found in sentence: []
# Block 225 processed with 3 nodes and 3 edges.
# Processing block 226...
# Total punctuations found in sentence: []
# Block 226 processed with 3 nodes and 3 edges.
# Processing block 227...
# Total punctuations found in sentence: []
# Block 227 processed with 4 nodes and 5 edges.
# Processing block 228...
# Total punctuations found in sentence: []
# Block 228 processed with 8 nodes and 9 edges.
# Processing block 229...
# Total punctuations found in sentence: []
# Block 229 processed with 2 nodes and 2 edges.
# Processing block 230...
# Total punctuations found in sentence: []
# Block 230 processed with 5 nodes and 6 edges.
# Processing block 231...
# Total punctuations found in sentence: []
# Block 231 processed with 1 nodes and 1 edges.
# Processing block 232...
# Total punctuations found in sentence: []
# Block 232 processed with 3 nodes and 3 edges.
# Processing block 233...
# Total punctuations found in sentence: []
# Block 233 processed with 4 nodes and 5 edges.
# Processing block 234...
# Total punctuations found in sentence: []
# Block 234 processed with 6 nodes and 8 edges.
# Processing block 235...
# Total punctuations found in sentence: []
# Block 235 processed with 2 nodes and 2 edges.
# Processing block 236...
# Total punctuations found in sentence: []
# Block 236 processed with 4 nodes and 5 edges.
# Processing block 237...
# Total punctuations found in sentence: []
# Block 237 processed with 4 nodes and 5 edges.
# Processing block 238...
# Total punctuations found in sentence: []
# Block 238 processed with 9 nodes and 10 edges.
# Processing block 239...
# Total punctuations found in sentence: []
# Block 239 processed with 6 nodes and 8 edges.
# Processing block 240...
# Total punctuations found in sentence: ['?']
# Block 240 processed with 5 nodes and 8 edges.
# Processing block 241...
# Total punctuations found in sentence: ['?']
# Block 241 processed with 3 nodes and 3 edges.
# Processing block 242...
# Total punctuations found in sentence: []
# Block 242 processed with 9 nodes and 9 edges.
# Processing block 243...
# Total punctuations found in sentence: []
# Block 243 processed with 17 nodes and 19 edges.
# Processing block 244...
# Total punctuations found in sentence: []
# Block 244 processed with 13 nodes and 14 edges.
# Processing block 245...
# Total punctuations found in sentence: []
# Block 245 processed with 6 nodes and 7 edges.
# Processing block 246...
# Total punctuations found in sentence: ['?']
# Block 246 processed with 5 nodes and 7 edges.
# Processing block 247...
# Total punctuations found in sentence: []
# Block 247 processed with 7 nodes and 11 edges.
# Processing block 248...
# Total punctuations found in sentence: []
# Block 248 processed with 4 nodes and 5 edges.
# Processing block 249...
# Total punctuations found in sentence: []
# Block 249 processed with 3 nodes and 4 edges.
# Processing block 250...
# Total punctuations found in sentence: []
# Block 250 processed with 4 nodes and 5 edges.
# Processing block 251...
# Total punctuations found in sentence: []
# Block 251 processed with 8 nodes and 9 edges.
# Processing block 252...
# Total punctuations found in sentence: []
# Block 252 processed with 8 nodes and 10 edges.
# Processing block 253...
# Total punctuations found in sentence: []
# Block 253 processed with 8 nodes and 11 edges.
# Processing block 254...
# Total punctuations found in sentence: ['?']
# Block 254 processed with 3 nodes and 3 edges.
# Processing block 255...
# Total punctuations found in sentence: []
# Block 255 processed with 5 nodes and 7 edges.
# Processing block 256...
# Total punctuations found in sentence: ['?']
# Block 256 processed with 7 nodes and 7 edges.
# Processing block 257...
# Total punctuations found in sentence: []
# Block 257 processed with 9 nodes and 11 edges.
# Processing block 258...
# Total punctuations found in sentence: []
# Block 258 processed with 3 nodes and 3 edges.
# Processing block 259...
# Total punctuations found in sentence: []
# Block 259 processed with 7 nodes and 9 edges.
# Processing block 260...
# Total punctuations found in sentence: []
# Block 260 processed with 11 nodes and 15 edges.
# Processing block 261...
# Total punctuations found in sentence: ['?']
# Block 261 processed with 2 nodes and 2 edges.
# Processing block 262...
# Total punctuations found in sentence: ['?']
# Block 262 processed with 4 nodes and 5 edges.
# Processing block 263...
# Total punctuations found in sentence: []
# Block 263 processed with 3 nodes and 3 edges.
# Processing block 264...
# Total punctuations found in sentence: []
# Block 264 processed with 6 nodes and 7 edges.
# Processing block 265...
# Total punctuations found in sentence: []
# Block 265 processed with 4 nodes and 6 edges.
# Processing block 266...
# Total punctuations found in sentence: []
# Block 266 processed with 11 nodes and 16 edges.
# Processing block 267...
# Total punctuations found in sentence: []
# Block 267 processed with 7 nodes and 8 edges.
# Processing block 268...
# Total punctuations found in sentence: []
# Block 268 processed with 9 nodes and 10 edges.
# Processing block 269...
# Total punctuations found in sentence: []
# Block 269 processed with 5 nodes and 5 edges.
# Processing block 270...
# Total punctuations found in sentence: []
# Block 270 processed with 2 nodes and 2 edges.
# Processing block 271...
# Total punctuations found in sentence: []
# Block 271 processed with 4 nodes and 5 edges.
# Processing block 272...
# Total punctuations found in sentence: []
# Block 272 processed with 5 nodes and 6 edges.
# Processing block 273...
# Total punctuations found in sentence: []
# Block 273 processed with 4 nodes and 5 edges.
# Processing block 274...
# Total punctuations found in sentence: [',', ',', ',']
# Block 274 processed with 27 nodes and 33 edges.
# Processing block 275...
# Total punctuations found in sentence: [',', ',']
# Block 275 processed with 23 nodes and 26 edges.
# Processing block 276...
# Total punctuations found in sentence: [',', ',', ',']
# Block 276 processed with 22 nodes and 25 edges.
# Processing block 277...
# Total punctuations found in sentence: [',', ',']
# Block 277 processed with 21 nodes and 26 edges.
# Processing block 278...
# Total punctuations found in sentence: [',', ',']
# Block 278 processed with 15 nodes and 18 edges.
# Processing block 279...
# Total punctuations found in sentence: [',']
# Block 279 processed with 13 nodes and 18 edges.
# Processing block 280...
# Total punctuations found in sentence: [',', ',', ',']
# Block 280 processed with 20 nodes and 24 edges.
# Processing block 281...
# Total punctuations found in sentence: [',', ',', ',']
# Block 281 processed with 28 nodes and 32 edges.
# Processing block 282...
# Total punctuations found in sentence: [',', ',', ',', ',']
# Block 282 processed with 32 nodes and 35 edges.
# Processing block 283...
# Total punctuations found in sentence: []
# Block 283 processed with 1 nodes and 1 edges.
# Processing block 284...
# Total punctuations found in sentence: []
# Block 284 processed with 2 nodes and 2 edges.
# Processing block 285...
# Total punctuations found in sentence: []
# Block 285 processed with 5 nodes and 5 edges.
# Processing block 286...
# Total punctuations found in sentence: []
# Block 286 processed with 7 nodes and 8 edges.
# Processing block 287...
# Total punctuations found in sentence: []
# Block 287 processed with 5 nodes and 7 edges.
# Processing block 288...
# Total punctuations found in sentence: []
# Block 288 processed with 8 nodes and 10 edges.
# Processing block 289...
# Total punctuations found in sentence: []
# Block 289 processed with 6 nodes and 6 edges.
# Processing block 290...
# Total punctuations found in sentence: []
# Block 290 processed with 7 nodes and 8 edges.
# Processing block 291...
# Total punctuations found in sentence: ['?']
# Block 291 processed with 5 nodes and 6 edges.
# Processing block 292...
# Total punctuations found in sentence: []
# Block 292 processed with 2 nodes and 2 edges.
# Processing block 293...
# Total punctuations found in sentence: []
# Block 293 processed with 2 nodes and 2 edges.
# Processing block 294...
# Total punctuations found in sentence: []
# Block 294 processed with 7 nodes and 10 edges.
# Processing block 295...
# Total punctuations found in sentence: []
# Block 295 processed with 3 nodes and 3 edges.
# Processing block 296...
# Total punctuations found in sentence: []
# Block 296 processed with 12 nodes and 14 edges.
# Processing block 297...
# Total punctuations found in sentence: []
# Block 297 processed with 3 nodes and 5 edges.
# Processing block 298...
# Total punctuations found in sentence: []
# Block 298 processed with 7 nodes and 7 edges.
# Processing block 299...
# Total punctuations found in sentence: []
# Block 299 processed with 3 nodes and 3 edges.
# Processing block 300...
# Total punctuations found in sentence: []
# Block 300 processed with 9 nodes and 13 edges.
# Processing block 301...
# Total punctuations found in sentence: []
# Block 301 processed with 1 nodes and 1 edges.
# Processing block 302...
# Total punctuations found in sentence: []
# Block 302 processed with 2 nodes and 3 edges.
# Processing block 303...
# Total punctuations found in sentence: []
# Block 303 processed with 3 nodes and 4 edges.
# Processing block 304...
# Total punctuations found in sentence: []
# Block 304 processed with 6 nodes and 7 edges.
# Processing block 305...
# Total punctuations found in sentence: []
# Block 305 processed with 6 nodes and 9 edges.
# Processing block 306...
# Total punctuations found in sentence: []
# Block 306 processed with 5 nodes and 6 edges.
# Processing block 307...
# Total punctuations found in sentence: []
# Block 307 processed with 6 nodes and 9 edges.
# Processing block 308...
# Total punctuations found in sentence: []
# Block 308 processed with 7 nodes and 9 edges.
# Processing block 309...
# Total punctuations found in sentence: []
# Block 309 processed with 8 nodes and 16 edges.
# Processing block 310...
# Total punctuations found in sentence: []
# Block 310 processed with 4 nodes and 7 edges.
# Processing block 311...
# Total punctuations found in sentence: []
# Block 311 processed with 6 nodes and 6 edges.
# Processing block 312...
# Total punctuations found in sentence: []
# Block 312 processed with 7 nodes and 8 edges.
# Processing block 313...
# Total punctuations found in sentence: []
# Block 313 processed with 3 nodes and 4 edges.
# Processing block 314...
# Total punctuations found in sentence: []
# Block 314 processed with 12 nodes and 15 edges.
# Processing block 315...
# Total punctuations found in sentence: []
# Block 315 processed with 11 nodes and 11 edges.
# Processing block 316...
# Total punctuations found in sentence: []
# Block 316 processed with 3 nodes and 3 edges.
# Processing block 317...
# Total punctuations found in sentence: []
# Block 317 processed with 4 nodes and 4 edges.
# Processing block 318...
# Total punctuations found in sentence: []
# Block 318 processed with 7 nodes and 7 edges.
# Processing block 319...
# Total punctuations found in sentence: ['?']
# Block 319 processed with 5 nodes and 6 edges.
# Processing block 320...
# Total punctuations found in sentence: []
# Block 320 processed with 7 nodes and 8 edges.
# Processing block 321...
# Total punctuations found in sentence: []
# Block 321 processed with 5 nodes and 8 edges.
# Processing block 322...
# Total punctuations found in sentence: []
# Block 322 processed with 6 nodes and 8 edges.
# Processing block 323...
# Total punctuations found in sentence: []
# Block 323 processed with 9 nodes and 12 edges.
# Processing block 324...
# Total punctuations found in sentence: []
# Block 324 processed with 9 nodes and 9 edges.
# Processing block 325...
# Total punctuations found in sentence: []
# Block 325 processed with 4 nodes and 4 edges.
# Processing block 326...
# Total punctuations found in sentence: []
# Block 326 processed with 5 nodes and 6 edges.
# Processing block 327...
# Total punctuations found in sentence: []
# Block 327 processed with 11 nodes and 12 edges.
# Processing block 328...
# Total punctuations found in sentence: []
# Block 328 processed with 4 nodes and 6 edges.
# Processing block 329...
# Total punctuations found in sentence: []
# Block 329 processed with 4 nodes and 4 edges.
# Processing block 330...
# Total punctuations found in sentence: []
# Block 330 processed with 10 nodes and 13 edges.
# Processing block 331...
# Total punctuations found in sentence: []
# Block 331 processed with 5 nodes and 6 edges.
# Processing block 332...
# Total punctuations found in sentence: []
# Block 332 processed with 3 nodes and 3 edges.
# Processing block 333...
# Total punctuations found in sentence: []
# Block 333 processed with 9 nodes and 13 edges.
# Processing block 334...
# Total punctuations found in sentence: []
# Block 334 processed with 3 nodes and 4 edges.
# Processing block 335...
# Total punctuations found in sentence: ['?']
# Block 335 processed with 3 nodes and 3 edges.
# Processing block 336...
# Total punctuations found in sentence: []
# Block 336 processed with 5 nodes and 6 edges.
# Processing block 337...
# Total punctuations found in sentence: []
# Block 337 processed with 5 nodes and 5 edges.
# Processing block 338...
# Total punctuations found in sentence: []
# Block 338 processed with 7 nodes and 8 edges.
# Processing block 339...
# Total punctuations found in sentence: []
# Block 339 processed with 2 nodes and 3 edges.
# Processing block 340...
# Total punctuations found in sentence: []
# Block 340 processed with 4 nodes and 4 edges.
# Processing block 341...
# Total punctuations found in sentence: []
# Block 341 processed with 1 nodes and 1 edges.
# Processing block 342...
# Total punctuations found in sentence: [',']
# Block 342 processed with 17 nodes and 19 edges.
# Processing block 343...
# Total punctuations found in sentence: []
# Block 343 processed with 17 nodes and 21 edges.
# Processing block 344...
# Total punctuations found in sentence: []
# Block 344 processed with 4 nodes and 4 edges.
# Processing block 345...
# Total punctuations found in sentence: []
# Block 345 processed with 2 nodes and 2 edges.
# Processing block 346...
# Total punctuations found in sentence: [',']
# Block 346 processed with 9 nodes and 12 edges.
# Processing block 347...
# Total punctuations found in sentence: [',', ',']
# Block 347 processed with 26 nodes and 35 edges.
# Processing block 348...
# Total punctuations found in sentence: []
# Block 348 processed with 2 nodes and 2 edges.
# Processing block 349...
# Total punctuations found in sentence: []
# Block 349 processed with 4 nodes and 4 edges.
# Processing block 350...
# Total punctuations found in sentence: []
# Block 350 processed with 2 nodes and 2 edges.
# Processing block 351...
# Total punctuations found in sentence: []
# Block 351 processed with 9 nodes and 9 edges.
# Processing block 352...
# Total punctuations found in sentence: []
# Block 352 processed with 6 nodes and 6 edges.
# Processing block 353...
# Total punctuations found in sentence: []
# Block 353 processed with 7 nodes and 7 edges.
# Processing block 354...
# Total punctuations found in sentence: []
# Block 354 processed with 7 nodes and 7 edges.
# Processing block 355...
# Total punctuations found in sentence: []
# Block 355 processed with 4 nodes and 4 edges.
# Processing block 356...
# Total punctuations found in sentence: []
# Block 356 processed with 3 nodes and 3 edges.
# Processing block 357...
# Total punctuations found in sentence: []
# Block 357 processed with 2 nodes and 2 edges.
# Processing block 358...
# Total punctuations found in sentence: [',']
# Block 358 processed with 18 nodes and 19 edges.
# Processing block 359...
# Total punctuations found in sentence: []
# Block 359 processed with 12 nodes and 12 edges.
# Processing block 360...
# Total punctuations found in sentence: [',']
# Block 360 processed with 10 nodes and 11 edges.
# Processing block 361...
# Total punctuations found in sentence: []
# Block 361 processed with 14 nodes and 14 edges.
# Processing block 362...
# Total punctuations found in sentence: []
# Block 362 processed with 3 nodes and 3 edges.
# Processing block 363...
# Total punctuations found in sentence: []
# Block 363 processed with 3 nodes and 3 edges.
# Processing block 364...
# Total punctuations found in sentence: []
# Block 364 processed with 1 nodes and 1 edges.
# Processing block 365...
# Total punctuations found in sentence: []
# Block 365 processed with 6 nodes and 8 edges.
# Processing block 366...
# Total punctuations found in sentence: []
# Block 366 processed with 8 nodes and 10 edges.
# Processing block 367...
# Total punctuations found in sentence: []
# Block 367 processed with 6 nodes and 9 edges.
# Processing block 368...
# Total punctuations found in sentence: []
# Block 368 processed with 6 nodes and 10 edges.
# Processing block 369...
# Total punctuations found in sentence: []
# Block 369 processed with 3 nodes and 3 edges.
# Processing block 370...
# Total punctuations found in sentence: []
# Block 370 processed with 3 nodes and 3 edges.
# Processing block 371...
# Total punctuations found in sentence: []
# Block 371 processed with 2 nodes and 2 edges.
# Processing block 372...
# Total punctuations found in sentence: [',', ',', ',']
# Block 372 processed with 18 nodes and 21 edges.
# Processing block 373...
# Total punctuations found in sentence: [',']
# Block 373 processed with 17 nodes and 19 edges.
# Processing block 374...
# Total punctuations found in sentence: []
# Block 374 processed with 11 nodes and 15 edges.
# Processing block 375...
# Total punctuations found in sentence: []
# Block 375 processed with 3 nodes and 3 edges.
# Processing block 376...
# Total punctuations found in sentence: []
# Block 376 processed with 3 nodes and 3 edges.
# Processing block 377...
# Total punctuations found in sentence: []
# Block 377 processed with 6 nodes and 8 edges.
# Processing block 378...
# Total punctuations found in sentence: []
# Block 378 processed with 4 nodes and 5 edges.
# Processing block 379...
# Total punctuations found in sentence: []
# Block 379 processed with 2 nodes and 2 edges.
# Processing block 380...
# Total punctuations found in sentence: []
# Block 380 processed with 2 nodes and 2 edges.
# Processing block 381...
# Total punctuations found in sentence: []
# Block 381 processed with 3 nodes and 3 edges.
# Processing block 382...
# Total punctuations found in sentence: []
# Block 382 processed with 4 nodes and 4 edges.
# Processing block 383...
# Total punctuations found in sentence: ['?']
# Block 383 processed with 8 nodes and 9 edges.
# Processing block 384...
# Total punctuations found in sentence: []
# Block 384 processed with 9 nodes and 11 edges.
# Processing block 385...
# Total punctuations found in sentence: []
# Block 385 processed with 2 nodes and 2 edges.
# Processing block 386...
# Total punctuations found in sentence: []
# Block 386 processed with 3 nodes and 3 edges.
# Processing block 387...
# Total punctuations found in sentence: []
# Block 387 processed with 10 nodes and 11 edges.
# Processing block 388...
# Total punctuations found in sentence: []
# Block 388 processed with 8 nodes and 11 edges.
# Processing block 389...
# Total punctuations found in sentence: []
# Block 389 processed with 2 nodes and 2 edges.
# Processing block 390...
# Total punctuations found in sentence: ['?']
# Block 390 processed with 10 nodes and 12 edges.
# Processing block 391...
# Total punctuations found in sentence: []
# Block 391 processed with 2 nodes and 2 edges.
# Processing block 392...
# Total punctuations found in sentence: []
# Block 392 processed with 4 nodes and 4 edges.
# Processing block 393...
# Total punctuations found in sentence: ['?']
# Block 393 processed with 13 nodes and 15 edges.
# Processing block 394...
# Total punctuations found in sentence: []
# Block 394 processed with 9 nodes and 11 edges.
# Processing block 395...
# Total punctuations found in sentence: []
# Block 395 processed with 3 nodes and 3 edges.
# Processing block 396...
# Total punctuations found in sentence: []
# Block 396 processed with 3 nodes and 3 edges.
# Processing block 397...
# Total punctuations found in sentence: []
# Block 397 processed with 4 nodes and 5 edges.
# Processing block 398...
# Total punctuations found in sentence: []
# Block 398 processed with 3 nodes and 3 edges.
# Processing block 399...
# Total punctuations found in sentence: []
# Block 399 processed with 16 nodes and 18 edges.
# Processing block 400...
# Total punctuations found in sentence: [',', ',']
# Block 400 processed with 34 nodes and 38 edges.
# Processing block 401...
# Total punctuations found in sentence: []
# Block 401 processed with 34 nodes and 40 edges.
# Processing block 402...
# Total punctuations found in sentence: [',']
# Block 402 processed with 15 nodes and 15 edges.
# Processing block 403...
# Total punctuations found in sentence: []
# Block 403 processed with 2 nodes and 2 edges.
# Processing block 404...
# Total punctuations found in sentence: []
# Block 404 processed with 4 nodes and 4 edges.
# Processing block 405...
# Total punctuations found in sentence: []
# Block 405 processed with 13 nodes and 15 edges.
# Processing block 406...
# Total punctuations found in sentence: []
# Block 406 processed with 10 nodes and 12 edges.
# Processing block 407...
# Total punctuations found in sentence: [',']
# Block 407 processed with 20 nodes and 26 edges.
# Processing block 408...
# Total punctuations found in sentence: []
# Block 408 processed with 2 nodes and 2 edges.
# Processing block 409...
# Total punctuations found in sentence: []
# Block 409 processed with 4 nodes and 4 edges.
# Processing block 410...
# Total punctuations found in sentence: []
# Block 410 processed with 1 nodes and 2 edges.
# Processing block 411...
# Total punctuations found in sentence: []
# Block 411 processed with 5 nodes and 8 edges.
# Processing block 412...
# Total punctuations found in sentence: []
# Block 412 processed with 2 nodes and 4 edges.
# Processing block 413...
# Total punctuations found in sentence: []
# Block 413 processed with 3 nodes and 5 edges.
# Processing block 414...
# Total punctuations found in sentence: []
# Block 414 processed with 2 nodes and 2 edges.
# Processing block 415...
# Total punctuations found in sentence: ['?']
# Block 415 processed with 5 nodes and 7 edges.
# Processing block 416...
# Total punctuations found in sentence: []
# Block 416 processed with 14 nodes and 17 edges.
# Processing block 417...
# Total punctuations found in sentence: [',', ',', ',']
# Block 417 processed with 30 nodes and 37 edges.
# Processing block 418...
# Total punctuations found in sentence: []
# Block 418 processed with 2 nodes and 2 edges.
# Processing block 419...
# Total punctuations found in sentence: ['?']
# Block 419 processed with 9 nodes and 10 edges.
# Processing block 420...
# Total punctuations found in sentence: []
# Block 420 processed with 3 nodes and 3 edges.
# Processing block 421...
# Total punctuations found in sentence: []
# Block 421 processed with 3 nodes and 3 edges.
# Processing block 422...
# Total punctuations found in sentence: [',', ',', ',', ',', ',']
# Block 422 processed with 26 nodes and 34 edges.
# Processing block 423...
# Total punctuations found in sentence: []
# Block 423 processed with 2 nodes and 4 edges.
# Processing block 424...
# Total punctuations found in sentence: [',']
# Block 424 processed with 9 nodes and 12 edges.
# Processing block 425...
# Total punctuations found in sentence: []
# Block 425 processed with 2 nodes and 3 edges.
# Processing block 426...
# Total punctuations found in sentence: []
# Block 426 processed with 4 nodes and 5 edges.
# Processing block 427...
# ...
# Block 3156 processed with 10 nodes and 10 edges.
# Processing block 3157...
# Total punctuations found in sentence: ['?']
# Block 3157 processed with 13 nodes and 14 edges.
# Processing block 3158...
# Total punctuations found in sentence: ['?']
# Block 3158 processed with 7 nodes and 8 edges.
# Processing block 3159...
# Total punctuations found in sentence: [',', ',', ',', ',']
# Block 3159 processed with 34 nodes and 39 edges.
# Processing block 3160...
# Total punctuations found in sentence: []
# Block 3160 processed with 22 nodes and 27 edges.
# Processing block 3161...
# Total punctuations found in sentence: [',', ',']
# Block 3161 processed with 32 nodes and 37 edges.
# Processing block 3162...
# Total punctuations found in sentence: [';']
# Block 3162 processed with 15 nodes and 19 edges.
# Processing block 3163...
# Total punctuations found in sentence: [';']
# Block 3163 processed with 47 nodes and 59 edges.
# Processing block 3164...
# Total punctuations found in sentence: [',', ',']
# Block 3164 processed with 36 nodes and 44 edges.
# Processing block 3165...
# Total punctuations found in sentence: [',']
# Block 3165 processed with 46 nodes and 51 edges.
# Processing block 3166...
# Total punctuations found in sentence: []
# Block 3166 processed with 13 nodes and 15 edges.
# Processing block 3167...
# Total punctuations found in sentence: [',', ',', ',', ',']
# Block 3167 processed with 69 nodes and 79 edges.
# Processing block 3168...
# Total punctuations found in sentence: [',', ',']
# Block 3168 processed with 36 nodes and 42 edges.
# Processing block 3169...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3169 processed with 51 nodes and 56 edges.
# Processing block 3170...
# Total punctuations found in sentence: [',', ',']
# Block 3170 processed with 13 nodes and 15 edges.
# Processing block 3171...
# Total punctuations found in sentence: [',', ',']
# Block 3171 processed with 25 nodes and 29 edges.
# Processing block 3172...
# Total punctuations found in sentence: [',']
# Block 3172 processed with 15 nodes and 20 edges.
# Processing block 3173...
# Total punctuations found in sentence: [',', ',']
# Block 3173 processed with 43 nodes and 52 edges.
# Processing block 3174...
# Total punctuations found in sentence: [',']
# Block 3174 processed with 18 nodes and 21 edges.
# Processing block 3175...
# Total punctuations found in sentence: [',', ';']
# Block 3175 processed with 39 nodes and 47 edges.
# Processing block 3176...
# Total punctuations found in sentence: [',', ',']
# Block 3176 processed with 22 nodes and 26 edges.
# Processing block 3177...
# Total punctuations found in sentence: []
# Block 3177 processed with 15 nodes and 17 edges.
# Processing block 3178...
# Total punctuations found in sentence: [',']
# Block 3178 processed with 39 nodes and 44 edges.
# Processing block 3179...
# Total punctuations found in sentence: []
# Block 3179 processed with 16 nodes and 19 edges.
# Processing block 3180...
# Total punctuations found in sentence: [',']
# Block 3180 processed with 16 nodes and 18 edges.
# Processing block 3181...
# Total punctuations found in sentence: [',']
# Block 3181 processed with 21 nodes and 25 edges.
# Processing block 3182...
# Total punctuations found in sentence: []
# Block 3182 processed with 15 nodes and 17 edges.
# Processing block 3183...
# Total punctuations found in sentence: []
# Block 3183 processed with 3 nodes and 3 edges.
# Processing block 3184...
# Total punctuations found in sentence: []
# Block 3184 processed with 1 nodes and 1 edges.
# Processing block 3185...
# Total punctuations found in sentence: []
# Block 3185 processed with 5 nodes and 5 edges.
# Processing block 3186...
# Total punctuations found in sentence: []
# Block 3186 processed with 5 nodes and 5 edges.
# Processing block 3187...
# Total punctuations found in sentence: []
# Block 3187 processed with 6 nodes and 6 edges.
# Processing block 3188...
# Total punctuations found in sentence: []
# Block 3188 processed with 18 nodes and 20 edges.
# Processing block 3189...
# Total punctuations found in sentence: [',']
# Block 3189 processed with 14 nodes and 16 edges.
# Processing block 3190...
# Total punctuations found in sentence: [';']
# Block 3190 processed with 7 nodes and 8 edges.
# Processing block 3191...
# Total punctuations found in sentence: [',', ',', ',', ',']
# Block 3191 processed with 46 nodes and 63 edges.
# Processing block 3192...
# Total punctuations found in sentence: [',', ',']
# Block 3192 processed with 24 nodes and 28 edges.
# Processing block 3193...
# Total punctuations found in sentence: []
# Block 3193 processed with 14 nodes and 16 edges.
# Processing block 3194...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3194 processed with 46 nodes and 55 edges.
# Processing block 3195...
# Total punctuations found in sentence: []
# Block 3195 processed with 23 nodes and 23 edges.
# Processing block 3196...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3196 processed with 36 nodes and 40 edges.
# Processing block 3197...
# Total punctuations found in sentence: [',']
# Block 3197 processed with 25 nodes and 28 edges.
# Processing block 3198...
# Total punctuations found in sentence: [',']
# Block 3198 processed with 16 nodes and 18 edges.
# Processing block 3199...
# Total punctuations found in sentence: [',', ',']
# Block 3199 processed with 40 nodes and 44 edges.
# Processing block 3200...
# Total punctuations found in sentence: [',', ';']
# Block 3200 processed with 21 nodes and 28 edges.
# Processing block 3201...
# Total punctuations found in sentence: []
# Block 3201 processed with 21 nodes and 24 edges.
# Processing block 3202...
# Total punctuations found in sentence: [',', ';']
# Block 3202 processed with 34 nodes and 38 edges.
# Processing block 3203...
# Total punctuations found in sentence: []
# Block 3203 processed with 19 nodes and 24 edges.
# Processing block 3204...
# Total punctuations found in sentence: [';', ';']
# Block 3204 processed with 32 nodes and 39 edges.
# Processing block 3205...
# Total punctuations found in sentence: [',', ',']
# Block 3205 processed with 26 nodes and 28 edges.
# Processing block 3206...
# Total punctuations found in sentence: [',']
# Block 3206 processed with 56 nodes and 65 edges.
# Processing block 3207...
# Total punctuations found in sentence: [',']
# Block 3207 processed with 18 nodes and 20 edges.
# Processing block 3208...
# Total punctuations found in sentence: []
# Block 3208 processed with 17 nodes and 20 edges.
# Processing block 3209...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3209 processed with 47 nodes and 54 edges.
# Processing block 3210...
# Total punctuations found in sentence: []
# Block 3210 processed with 18 nodes and 22 edges.
# Processing block 3211...
# Total punctuations found in sentence: []
# Block 3211 processed with 2 nodes and 2 edges.
# Processing block 3212...
# Total punctuations found in sentence: []
# Block 3212 processed with 1 nodes and 1 edges.
# Processing block 3213...
# Total punctuations found in sentence: []
# Block 3213 processed with 3 nodes and 4 edges.
# Processing block 3214...
# Total punctuations found in sentence: []
# Block 3214 processed with 4 nodes and 4 edges.
# Processing block 3215...
# Total punctuations found in sentence: []
# Block 3215 processed with 4 nodes and 4 edges.
# Processing block 3216...
# Total punctuations found in sentence: []
# Block 3216 processed with 5 nodes and 5 edges.
# Processing block 3217...
# Total punctuations found in sentence: []
# Block 3217 processed with 12 nodes and 14 edges.
# Processing block 3218...
# Total punctuations found in sentence: []
# Block 3218 processed with 12 nodes and 15 edges.
# Processing block 3219...
# Total punctuations found in sentence: [',']
# Block 3219 processed with 24 nodes and 29 edges.
# Processing block 3220...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3220 processed with 17 nodes and 20 edges.
# Processing block 3221...
# Total punctuations found in sentence: [',', ',']
# Block 3221 processed with 15 nodes and 16 edges.
# Processing block 3222...
# Total punctuations found in sentence: []
# Block 3222 processed with 4 nodes and 5 edges.
# Processing block 3223...
# Total punctuations found in sentence: [',']
# Block 3223 processed with 4 nodes and 6 edges.
# Processing block 3224...
# Total punctuations found in sentence: [',']
# Block 3224 processed with 16 nodes and 20 edges.
# Processing block 3225...
# Total punctuations found in sentence: [',']
# Block 3225 processed with 22 nodes and 24 edges.
# Processing block 3226...
# Total punctuations found in sentence: []
# Block 3226 processed with 13 nodes and 17 edges.
# Processing block 3227...
# Total punctuations found in sentence: []
# Block 3227 processed with 7 nodes and 9 edges.
# Processing block 3228...
# Total punctuations found in sentence: []
# Block 3228 processed with 18 nodes and 23 edges.
# Processing block 3229...
# Total punctuations found in sentence: []
# Block 3229 processed with 15 nodes and 17 edges.
# Processing block 3230...
# Total punctuations found in sentence: [',', ',']
# Block 3230 processed with 21 nodes and 28 edges.
# Processing block 3231...
# Total punctuations found in sentence: [',', ',']
# Block 3231 processed with 13 nodes and 17 edges.
# Processing block 3232...
# Total punctuations found in sentence: [',']
# Block 3232 processed with 28 nodes and 35 edges.
# Processing block 3233...
# Total punctuations found in sentence: []
# Block 3233 processed with 13 nodes and 17 edges.
# Processing block 3234...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3234 processed with 27 nodes and 31 edges.
# Processing block 3235...
# Total punctuations found in sentence: [',']
# Block 3235 processed with 13 nodes and 15 edges.
# Processing block 3236...
# Total punctuations found in sentence: []
# Block 3236 processed with 6 nodes and 6 edges.
# Processing block 3237...
# Total punctuations found in sentence: [',', ',']
# Block 3237 processed with 30 nodes and 36 edges.
# Processing block 3238...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3238 processed with 48 nodes and 57 edges.
# Processing block 3239...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3239 processed with 30 nodes and 42 edges.
# Processing block 3240...
# Total punctuations found in sentence: [',']
# Block 3240 processed with 16 nodes and 20 edges.
# Processing block 3241...
# Total punctuations found in sentence: [',']
# Block 3241 processed with 18 nodes and 27 edges.
# Processing block 3242...
# Total punctuations found in sentence: []
# Block 3242 processed with 23 nodes and 28 edges.
# Processing block 3243...
# Total punctuations found in sentence: [',']
# Block 3243 processed with 16 nodes and 19 edges.
# Processing block 3244...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3244 processed with 39 nodes and 49 edges.
# Processing block 3245...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3245 processed with 55 nodes and 68 edges.
# Processing block 3246...
# Total punctuations found in sentence: [',', ',']
# Block 3246 processed with 14 nodes and 16 edges.
# Processing block 3247...
# Total punctuations found in sentence: [',']
# Block 3247 processed with 18 nodes and 21 edges.
# Processing block 3248...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3248 processed with 29 nodes and 32 edges.
# Processing block 3249...
# Total punctuations found in sentence: [',']
# Block 3249 processed with 41 nodes and 48 edges.
# Processing block 3250...
# Total punctuations found in sentence: []
# Block 3250 processed with 2 nodes and 3 edges.
# Processing block 3251...
# Total punctuations found in sentence: []
# Block 3251 processed with 3 nodes and 4 edges.
# Processing block 3252...
# Total punctuations found in sentence: []
# Block 3252 processed with 9 nodes and 9 edges.
# Processing block 3253...
# Total punctuations found in sentence: []
# Block 3253 processed with 5 nodes and 5 edges.
# Processing block 3254...
# Total punctuations found in sentence: []
# Block 3254 processed with 2 nodes and 3 edges.
# Processing block 3255...
# Total punctuations found in sentence: [',']
# Block 3255 processed with 24 nodes and 27 edges.
# Processing block 3256...
# Total punctuations found in sentence: []
# Block 3256 processed with 16 nodes and 17 edges.
# Processing block 3257...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3257 processed with 34 nodes and 38 edges.
# Processing block 3258...
# Total punctuations found in sentence: [',']
# Block 3258 processed with 15 nodes and 21 edges.
# Processing block 3259...
# Total punctuations found in sentence: [',', ',']
# Block 3259 processed with 47 nodes and 50 edges.
# Processing block 3260...
# Total punctuations found in sentence: [',']
# Block 3260 processed with 17 nodes and 19 edges.
# Processing block 3261...
# Total punctuations found in sentence: [',', ',']
# Block 3261 processed with 35 nodes and 42 edges.
# Processing block 3262...
# Total punctuations found in sentence: [',']
# Block 3262 processed with 23 nodes and 29 edges.
# Processing block 3263...
# Total punctuations found in sentence: [',', ',']
# Block 3263 processed with 25 nodes and 28 edges.
# Processing block 3264...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3264 processed with 43 nodes and 54 edges.
# Processing block 3265...
# Total punctuations found in sentence: [',', ',', ',']
# Block 3265 processed with 26 nodes and 31 edges.
# Processing block 3266...
# Total punctuations found in sentence: [',', ',', ',', ',', ',']
# Block 3266 processed with 55 nodes and 61 edges.
# Processing block 3267...
# Total punctuations found in sentence: []
# Block 3267 processed with 15 nodes and 18 edges.
# Processing block 3268...
# Total punctuations found in sentence: []
# Block 3268 processed with 16 nodes and 19 edges.
# Processing block 3269...
# Total punctuations found in sentence: [',', ',', ',', ',']
# Block 3269 processed with 50 nodes and 56 edges.
# Processing block 3270...
# Total punctuations found in sentence: [',']
# Block 3270 processed with 20 nodes and 26 edges.
# Processing block 3271...
# Total punctuations found in sentence: [',', ',']
# Block 3271 processed with 25 nodes and 31 edges.
# Processing block 3272...
# Total punctuations found in sentence: [',', ',']
# Block 3272 processed with 29 nodes and 33 edges.
# Processing block 3273...
# Total punctuations found in sentence: [',']
# Block 3273 processed with 26 nodes and 31 edges.
# Processing block 3274...
# Total punctuations found in sentence: [',', ',']
# Block 3274 processed with 54 nodes and 58 edges.
# Processing block 3275...
# Total punctuations found in sentence: [',', ',']
# Block 3275 processed with 41 nodes and 44 edges.
# Processing block 3276...
# Total punctuations found in sentence: []
# Block 3276 processed with 15 nodes and 18 edges.
# Processing block 3277...
# Total punctuations found in sentence: []
# Block 3277 processed with 40 nodes and 42 edges.
# Processing block 3278...
# Total punctuations found in sentence: []
# Block 3278 processed with 2 nodes and 2 edges.
# Processing block 3279...
# Total punctuations found in sentence: []
# Block 3279 processed with 2 nodes and 2 edges.
# Processing block 3280...
# Total punctuations found in sentence: []
# Block 3280 processed with 1 nodes and 1 edges.
# Processing block 3281...
# Total punctuations found in sentence: []
# Block 3281 processed with 6 nodes and 7 edges.
# Processing block 3282...
# Total punctuations found in sentence: []
# Block 3282 processed with 4 nodes and 4 edges.
# Processing block 3283...
# Total punctuations found in sentence: []
# Block 3283 processed with 8 nodes and 9 edges.
# Processing block 3284...
# Total punctuations found in sentence: [',', ',']
# Block 3284 processed with 12 nodes and 15 edges.
# Processing block 3285...
# Total punctuations found in sentence: [',']
# Block 3285 processed with 16 nodes and 20 edges.
# Processing block 3286...
# Total punctuations found in sentence: [',']
# Block 3286 processed with 11 nodes and 14 edges.
# Processing block 3287...
# Total punctuations found in sentence: [',']
# Block 3287 processed with 15 nodes and 17 edges.
# Processing block 3288...
# Total punctuations found in sentence: []
# Block 3288 processed with 9 nodes and 10 edges.
# Processing block 3289...
# Total punctuations found in sentence: []
# Block 3289 processed with 16 nodes and 18 edges.
# Saved dep_graphs_dict to ./splits_blind_testset/dep_graph_blind_testset.json

# %% [markdown]
# # Sanity check that merging is correct

# %%
import pandas as pd

# If dataset is not a DataFrame already, convert it
if not isinstance(dataset, pd.DataFrame):
    df_dataset = pd.DataFrame(dataset)
else:
    df_dataset = dataset.copy()

# Build DataFrame from successfully parsed blocks
df_feats = pd.DataFrame(features_list)

# Ensure df_dataset has both Sentence and labels columns
assert "Sentence" in df_dataset.columns

# Merge features with original data 
merged_df = df_feats.merge(df_dataset[["Sentence"]], on="Sentence", how="left")

# i want to know how many sentences are in the dataset that are not in the features_list
missing_sentences = set(df_dataset["Sentence"]) - set(df_feats["Sentence"])
print(f"Number of sentences in dataset not found in features: {len(missing_sentences)}")
print("Some missing sentences:", missing_sentences)  # Show a few missing sentences
# Out:
# Number of sentences in dataset not found in features: 0
# Some missing sentences: set()
